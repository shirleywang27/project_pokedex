# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 15px; height: 80px">
#
# # Project 1
#
# ### Building "Pokemon Stay"
#
# ---
# You are an analyst at a "scrappy" online gaming company that specializes in remakes of last year's fads.
#
# Your boss, who runs the product development team, is convinced that Pokemon Go's fatal flaw was that you had to actually move around outside. She has design mock-ups for a new game called Pokemon Stay: in this version players still need to move, but just from website to website. Pokemon gyms are now popular online destinations, and catching Pokemon in the "wild" simply requires browsing the internet for hours in the comfort of your home.
#
# She wants you to program a prototype version of the game, and analyze the planned content to help the team calibrate the design.

# %% [markdown]
# #### Package imports
#
# The pprint package below is the only package imported here, and it's not even strictly required to do any of the project. Printing python variables and objects with pprint can help to format them in a "prettier" way.

# %%
from pprint import pprint

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 1. Defining a player
#
# ---
#
# The player variables are:
#
#     player_id : id code unique to each player (integer)
#     player_name : entered name of the player (string)
#     time_played : number of time played the game in minutes (float)
#     player_pokemon: the player's captured pokemon (dictionary)
#     gyms_visited: ids of the gyms that a player has visited (list)
#
# Create the components for a player object by defining each of these variables. The dictionary and list variables should just be defined as empty; you can use any (correctly typed) values for the others.

# %%
player_id = 1
player_name = 'Greg'
time_played = 10.3
player_pokemon = { }
gyms_visited = [ 'reddit.com', 'quora.com' ]

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 2. Defining "gym" locations
#
# ---
#
# As the sole programmer, Pokemon Stay will have to start small. To begin, there will be 10 different gym location websites on the internet. The gym locations are:
#
#     1. 'reddit.com'
#     2. 'amazon.com'
#     3. 'twitter.com'
#     4. 'linkedin.com'
#     5. 'ebay.com'
#     6. 'netflix.com'
#     7. 'amazon.com'
#     8. 'stackoverflow.com'
#     9. 'github.com'
#     10. 'quora.com'
#
# 1. Set up a list of all the gym locations. This will be a list of strings.
# 2. Append two of these locations to your player's list of visited gyms.
# 3. Print the list.

# %%
gym_locations = ['reddit.com', 
                 'amazon.com',
                 'twitter.com',
                 'linkedin.com',
                 'ebay.com',
                 'netflix.com',
                 'amazon.com',
                 'stackoverflow.com',
                 'github.com',
                 'quora.com']

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 3. Create a pokedex
#
# ---
#
# We also need to create some pokemon to catch. Each pokemon will be defined by these variables:
#
#     pokemon_id : unique identifier for each pokemon (integer)
#     name : the name of the pokemon (string)
#     type : the category of pokemon (string)
#     hp : base hitpoints (integer)
#     attack : base attack (integer)
#     defense : base defense (integer)
#     special_attack : base special attack (integer)
#     special_defense : base sepecial defense (integer)
#     speed : base speed (integer)
#
# We are only going to create 3 different pokemon with these `pokemon_id` and `pokemon_name` values:
#
#     1 : 'charmander'
#     2 : 'squirtle'
#     3 : 'bulbasaur'
#
# Create a dictionary that will contain the pokemon. The keys of the dictionary will be the `pokemon_id` and the values will themselves dictionaries that contain the other pokemon variables. The structure of the pokedex dictionary will start like so:
#
#      {
#          1: {
#                  'name':'charmander',
#                  'type':'fire',
#                  ...
#
# The `type` of charmander, squirtle, and bulbasaur should be `'fire'`, `'water'`, and `'poison'` respectively. The other values are up to you, make them anything you like!
#
# Print (or pretty print) the pokedex dictionary with the 3 pokemon.

# %%
pokedex = {
    1: { 'name': 'charmander',
         'type': 'fire',
         'hp': 100,
         'attack': 100,
         'defense' : 100,
         'special_attack': 200,
         'special_defense': 200,
         'speed': 50 
       },
     2 : {'name': 'squirtle',
          'type': 'water',
          'hp': 100,
          'attack': 100,
          'defense' : 100,
          'special_attack': 200,
          'special_defense': 200,
          'speed': 50
         },
     3 : {'name': 'bulbasaur',
          'type' : 'poison',
          'hp': 100,
          'attack': 100,
          'defense' : 100,
          'special_attack': 200,
          'special_defense': 200,
          'speed': 50
         }
}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 4. Create a data structure for players
#
# ---
#
# ### 4.1
#
# In order to maintain a database of multiple players, create a dictionary that keeps track of players indexed by `player_id`.
#
# The keys of the dictionary will be `player_id` and values will be dictionaries containing each player's variables (from question 1).
#
# Construct the `players` dictionary and insert the player that you defined in question 1, then print `players`.

# %%
players = {
    1: {
        'player_id': player_id,
        'player_name': player_name,
        'time_played': time_played,
        'player_pokemon': player_pokemon,
        'gyms_visited': gyms_visited
    }
    
}

# %% [markdown]
# ---
#
# ### 4.2
#
# Create a new player with `player_id = 2` in the `players` dictionary. Leave the `'player_pokemon'` dictionary empty. Append `'alcatraz'` and `'pacific_beach'` to the `'gyms_visited'` list for player 2.
#
# The `'player_name'` and `'time_played'` values are up to you, but must be a string and float, respectively.
#
# Remember, the player_id is the key for the player in the players dictionary.
#
# Print the `players` dictionary with the new player inserted.

# %%
players[2] = {
    'player_id': 2,
    'player_name': 'KK',
    'time_played': 3252353234.0,
    'player_pokemon': {},
    'gyms_visited': ['alcatraz', 'pacific_beach']
}

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 5. Add captured pokemon for each player
#
# ---
#
# The `'player_pokemon'` keyed dictionaries for each player keep track of which of the pokemon each player has.
#
# The keys of the `'player_pokemon'` dictionaries are the pokemon ids that correspond to the ids in the `pokedex` dictionary you created earlier. The values are integers specifying the stats for the pokemon.
#
# Give player 1 a squirtle. Give player 2 charmander and a bulbasaur.
#
# Print the players dictionary after adding the pokemon for each player.

# %%
players[1]['player_pokemon'][1] = pokedex[1]
players[2]['player_pokemon'][2] = pokedex[2]

# %%
players
# Out:
# {1: {'gyms_visited': ['reddit.com', 'quora.com'],
#   'player_id': 1,
#   'player_name': 'Greg',
#   'player_pokemon': {1: {'attack': 100,
#     'defense': 100,
#     'hp': 100,
#     'name': 'charmander',
#     'special_attack': 200,
#     'special_defense': 200,
#     'speed': 50,
#     'type': 'fire'}},
#   'time_played': 10.3},
#  2: {'gyms_visited': ['alcatraz', 'pacific_beach'],
#   'player_id': 2,
#   'player_name': 'KK',
#   'player_pokemon': {2: {'attack': 100,
#     'defense': 100,
#     'hp': 100,
#     'name': 'squirtle',
#     'special_attack': 200,
#     'special_defense': 200,
#     'speed': 50,
#     'type': 'water'}},
#   'time_played': 3252353234.0}}

# %% [markdown]
# ## 6. What gyms have players visited?
#
# ---
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.1
#
# Write a for-loop that:
#
# 1. Iterates through the `pokemon_gyms` list of gym locations you defined before.
# 2. For each gym, iterate through each player in the `players` dictionary with a second, internal for-loop.
# 3. If the player has visited the gym, print out "[player] has visited [gym location].", filling in [player] and [gym location] with the current player's name and current gym location.

# %%
for gym in gym_locations:
    for player in players:
        if gym in players[player]['gyms_visited']:
            print players[player]['player_name'],"has visited", gym
# Out:
# Greg has visited reddit.com
# Greg has visited quora.com

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 6.2
#
# How many times did that loop run? If you have N gyms and also N players, how many times would it run as a function of N?
#
# Can you think of a more efficient way to accomplish the same thing?
#
# (You can write your answer as Markdown text.)

# %% [markdown]
# That ran **20** times.

# %%
gym_locations_set = set(gym_locations)
for player in players:
    for gym_location in players[player]['gyms_visited']:
        if gym_location in gym_locations_set:
            print players[player]['player_name'],"has visited",gym_location
# Out:
# Greg has visited reddit.com
# Greg has visited quora.com

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 7. Calculate player "power".
#
# ---
#
# Define a function that will calculate a player's "power". Player power is defined as the sum of the base statistics all of their pokemon.
#
# Your function will:
#
# 1. Accept the `players` dictionary, `pokedex` dictionary, and a player_id as arguments.
# 2. For the specified player_id, look up that player's pokemon and their level(s).
# 3. Find and aggregate the attack and defense values for each of the player's pokemon from the `pokedex` dictionary.
# 4. Print "[player name]'s power is [player power].", where the player power is the sum of the base statistics for all of their pokemon.
# 5. Return the player's power value.
#
# Print out the pokemon power for each of your players.

# %%
def player_power(dictionary_of_players, pokedex_dictionary, player_id):
    the_player = dictionary_of_players[player_id]
    their_pokemon = the_player['player_pokemon']
    total_power = 0
    for poke in their_pokemon.values():
        total_power += poke['attack'] + poke['defense']
        #print "Working on",poke
        #print "Added",poke['attack'],"and", poke['defense'], "to get ",total_power
    print the_player['player_name']+"'s power is",total_power
    print "%s's power is %d" % (the_player['player_name'], total_power)
    print "{name}'s power is {power}".format(name= the_player['player_name'],
                                             power=total_power)
    return total_power

player_power(players, pokedex, 1)
# Out:
# Greg's power is 200
# Greg's power is 200
# Greg's power is 200
# 200

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 8. Load a pokedex file containing all the pokemon
#
# ---
#
# ### 8.1
#
# While you were putting together the prototype code, your colleagues were preparing a dataset of Pokemon and their attributes. (This was a rush job, so they may have picked some crazy values for some...)
#
# The code below loads information from a comma separated value (csv) file. You need to parse this string into a more useable format. The format of the string is:
#
# - Rows are separated by newline characters: \n
# - Columns are separated by commas: ,
# - All cells in the csv are double quoted. Ex: "PokedexNumber" is the first cell of the first row.
#
#
# Using for-loops, create a list of lists where each list within the overall list is a row of the csv/matrix, and each element in that list is a cell in that row. Additional criteria:
#
# 1. Quotes are removed from each cell item.
# 2. Numeric column values are converted to floats.
# 3. There are some cells that are empty and have no information. For these cells put a -1 value in place.
#
# Your end result is effectively a matrix. Each list in the outer list is a row, and the *j*th elements of list together form the *j*th column, which represents a data attribute. The first three lists in your pokedex list should look like this:
#
#     ['PokedexNumber', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense', 'SpecialAttack', 'SpecialDefense', 'Speed']
#     [1.0, 'Bulbasaur', 'GrassPoison', 318.0, 45.0, 49.0, 49.0, 65.0, 65.0, 45.0]
#     [2.0, 'Ivysaur', 'GrassPoison', 405.0, 60.0, 62.0, 63.0, 80.0, 80.0, 60.0]

# %%
# Code to read in pokedex info
import pandas
pokedex_file = pandas.read_csv('pokedex_basic.csv')
pokedex_file['MyNewIndex'] = pokedex_file.PokedexNumber
pokedex_file.set_index('MyNewIndex', inplace=True)
pokedex_file
    
# the pokedex string is assigned to the raw_pd variable
# Out:
#             PokedexNumber                       Name            Type  Total  \
# MyNewIndex
# 1                       1                  Bulbasaur     GrassPoison    318
# 2                       2                    Ivysaur     GrassPoison    405
# 3                       3                   Venusaur     GrassPoison    525
# 3                       3      VenusaurMega Venusaur     GrassPoison    625
# 4                       4                 Charmander            Fire    309
# 5                       5                 Charmeleon            Fire    405
# 6                       6                  Charizard      FireFlying    534
# 6                       6  CharizardMega Charizard X      FireDragon    634
# 6                       6  CharizardMega Charizard Y      FireFlying    634
# 7                       7                   Squirtle           Water    314
# 8                       8                  Wartortle           Water    405
# 9                       9                  Blastoise           Water    530
# 9                       9    BlastoiseMega Blastoise           Water    630
# 10                     10                   Caterpie             Bug    195
# 11                     11                    Metapod             Bug    205
# 12                     12                 Butterfree       BugFlying    395
# 13                     13                     Weedle       BugPoison    195
# 14                     14                     Kakuna       BugPoison    205
# 15                     15                   Beedrill       BugPoison    395
# 15                     15      BeedrillMega Beedrill       BugPoison    495
# 16                     16                     Pidgey    NormalFlying    251
# 17                     17                  Pidgeotto    NormalFlying    349
# 18                     18                    Pidgeot    NormalFlying    479
# 18                     18        PidgeotMega Pidgeot    NormalFlying    579
# 19                     19                    Rattata          Normal    253
# 20                     20                   Raticate          Normal    413
# 21                     21                    Spearow    NormalFlying    262
# 22                     22                     Fearow    NormalFlying    442
# 23                     23                      Ekans          Poison    288
# 24                     24                      Arbok          Poison    438
# ...                   ...                        ...             ...    ...
# 700                   700                    Sylveon           Fairy    525
# 701                   701                   Hawlucha  FightingFlying    500
# 702                   702                    Dedenne   ElectricFairy    431
# 703                   703                    Carbink       RockFairy    500
# 704                   704                      Goomy          Dragon    300
# 705                   705                    Sliggoo          Dragon    452
# 706                   706                     Goodra          Dragon    600
# 707                   707                     Klefki      SteelFairy    470
# 708                   708                   Phantump      GhostGrass    309
# 709                   709                  Trevenant      GhostGrass    474
# 710                   710      PumpkabooAverage Size      GhostGrass    335
# 710                   710        PumpkabooSmall Size      GhostGrass    335
# 710                   710        PumpkabooLarge Size      GhostGrass    335
# 710                   710        PumpkabooSuper Size      GhostGrass    335
# 711                   711      GourgeistAverage Size      GhostGrass    494
# 711                   711        GourgeistSmall Size      GhostGrass    494
# 711                   711        GourgeistLarge Size      GhostGrass    494
# 711                   711        GourgeistSuper Size      GhostGrass    494
# 712                   712                   Bergmite             Ice    304
# 713                   713                    Avalugg             Ice    514
# 714                   714                     Noibat    FlyingDragon    245
# 715                   715                    Noivern    FlyingDragon    535
# 716                   716                    Xerneas           Fairy    680
# 717                   717                    Yveltal      DarkFlying    680
# 718                   718              Zygarde Forme    DragonGround    600
# 719                   719                    Diancie       RockFairy    600
# 719                   719        DiancieMega Diancie       RockFairy    700
# 720                   720        HoopaHoopa Confined    PsychicGhost    600
# 720                   720         HoopaHoopa Unbound     PsychicDark    680
# 721                   721                  Volcanion       FireWater    600
#
#              HP  Attack  Defense  SpecialAttack  SpecialDefense  Speed
# MyNewIndex
# 1            45      49       49             65              65     45
# 2            60      62       63             80              80     60
# 3            80      82       83            100             100     80
# 3            80     100      123            122             120     80
# 4            39      52       43             60              50     65
# 5            58      64       58             80              65     80
# 6            78      84       78            109              85    100
# 6            78     130      111            130              85    100
# 6            78     104       78            159             115    100
# 7            44      48       65             50              64     43
# 8            59      63       80             65              80     58
# 9            79      83      100             85             105     78
# 9            79     103      120            135             115     78
# 10           45      30       35             20              20     45
# 11           50      20       55             25              25     30
# 12           60      45       50             90              80     70
# 13           40      35       30             20              20     50
# 14           45      25       50             25              25     35
# 15           65      90       40             45              80     75
# 15           65     150       40             15              80    145
# 16           40      45       40             35              35     56
# 17           63      60       55             50              50     71
# 18           83      80       75             70              70    101
# 18           83      80       80            135              80    121
# 19           30      56       35             25              35     72
# 20           55      81       60             50              70     97
# 21           40      60       30             31              31     70
# 22           65      90       65             61              61    100
# 23           35      60       44             40              54     55
# 24           60      85       69             65              79     80
# ...         ...     ...      ...            ...             ...    ...
# 700          95      65       65            110             130     60
# 701          78      92       75             74              63    118
# 702          67      58       57             81              67    101
# 703          50      50      150             50             150     50
# 704          45      50       35             55              75     40
# 705          68      75       53             83             113     60
# 706          90     100       70            110             150     80
# 707          57      80       91             80              87     75
# 708          43      70       48             50              60     38
# 709          85     110       76             65              82     56
# 710          49      66       70             44              55     51
# 710          44      66       70             44              55     56
# 710          54      66       70             44              55     46
# 710          59      66       70             44              55     41
# 711          65      90      122             58              75     84
# 711          55      85      122             58              75     99
# 711          75      95      122             58              75     69
# 711          85     100      122             58              75     54
# 712          55      69       85             32              35     28
# 713          95     117      184             44              46     28
# 714          40      30       35             45              40     55
# 715          85      70       80             97              80    123
# 716         126     131       95            131              98     99
# 717         126     131       95            131              98     99
# 718         108     100      121             81              95     95
# 719          50     100      150            100             150     50
# 719          50     160      110            160             110    110
# 720          80     110       60            150             130     70
# 720          80     160       60            170             130     80
# 721          80     110      120            130              90     70
#
# [800 rows x 10 columns]

# %%
pokedex_file.loc[3]
# Out:
#             PokedexNumber                   Name         Type  Total  HP  \
# MyNewIndex
# 3                       3               Venusaur  GrassPoison    525  80
# 3                       3  VenusaurMega Venusaur  GrassPoison    625  80
#
#             Attack  Defense  SpecialAttack  SpecialDefense  Speed
# MyNewIndex
# 3               82       83            100             100     80
# 3              100      123            122             120     80

# %%
pokedex_file[pokedex_file.PokedexNumber.duplicated()]
# Out:
#             PokedexNumber                       Name             Type  Total  \
# MyNewIndex
# 3                       3      VenusaurMega Venusaur      GrassPoison    625
# 6                       6  CharizardMega Charizard X       FireDragon    634
# 6                       6  CharizardMega Charizard Y       FireFlying    634
# 9                       9    BlastoiseMega Blastoise            Water    630
# 15                     15      BeedrillMega Beedrill        BugPoison    495
# 18                     18        PidgeotMega Pidgeot     NormalFlying    579
# 65                     65      AlakazamMega Alakazam          Psychic    590
# 80                     80        SlowbroMega Slowbro     WaterPsychic    590
# 94                     94          GengarMega Gengar      GhostPoison    600
# 115                   115  KangaskhanMega Kangaskhan           Normal    590
# 127                   127          PinsirMega Pinsir        BugFlying    600
# 130                   130      GyaradosMega Gyarados        WaterDark    640
# 142                   142  AerodactylMega Aerodactyl       RockFlying    615
# 150                   150        MewtwoMega Mewtwo X  PsychicFighting    800
# 150                   150        MewtwoMega Mewtwo Y          Psychic    780
# 181                   181      AmpharosMega Ampharos   ElectricDragon    610
# 208                   208        SteelixMega Steelix      SteelGround    610
# 212                   212          ScizorMega Scizor         BugSteel    600
# 214                   214    HeracrossMega Heracross      BugFighting    600
# 229                   229      HoundoomMega Houndoom         DarkFire    600
# 248                   248    TyranitarMega Tyranitar         RockDark    700
# 254                   254      SceptileMega Sceptile      GrassDragon    630
# 257                   257      BlazikenMega Blaziken     FireFighting    630
# 260                   260      SwampertMega Swampert      WaterGround    635
# 282                   282    GardevoirMega Gardevoir     PsychicFairy    618
# 302                   302        SableyeMega Sableye        DarkGhost    480
# 303                   303          MawileMega Mawile       SteelFairy    480
# 306                   306          AggronMega Aggron            Steel    630
# 308                   308      MedichamMega Medicham  FightingPsychic    510
# 310                   310    ManectricMega Manectric         Electric    575
# ...                   ...                        ...              ...    ...
# 445                   445      GarchompMega Garchomp     DragonGround    700
# 448                   448        LucarioMega Lucario    FightingSteel    625
# 460                   460    AbomasnowMega Abomasnow         GrassIce    594
# 475                   475        GalladeMega Gallade  PsychicFighting    618
# 479                   479            RotomHeat Rotom     ElectricFire    520
# 479                   479            RotomWash Rotom    ElectricWater    520
# 479                   479           RotomFrost Rotom      ElectricIce    520
# 479                   479             RotomFan Rotom   ElectricFlying    520
# 479                   479             RotomMow Rotom    ElectricGrass    520
# 487                   487       GiratinaOrigin Forme      GhostDragon    680
# 492                   492           ShayminSky Forme      GrassFlying    600
# 531                   531          AudinoMega Audino      NormalFairy    545
# 555                   555         DarmanitanZen Mode      FirePsychic    540
# 641                   641      TornadusTherian Forme           Flying    580
# 642                   642     ThundurusTherian Forme   ElectricFlying    580
# 645                   645      LandorusTherian Forme     GroundFlying    600
# 646                   646         KyuremBlack Kyurem        DragonIce    700
# 646                   646         KyuremWhite Kyurem        DragonIce    700
# 647                   647       KeldeoResolute Forme    WaterFighting    580
# 648                   648    MeloettaPirouette Forme   NormalFighting    600
# 678                   678             MeowsticFemale          Psychic    466
# 681                   681      AegislashShield Forme       SteelGhost    520
# 710                   710        PumpkabooSmall Size       GhostGrass    335
# 710                   710        PumpkabooLarge Size       GhostGrass    335
# 710                   710        PumpkabooSuper Size       GhostGrass    335
# 711                   711        GourgeistSmall Size       GhostGrass    494
# 711                   711        GourgeistLarge Size       GhostGrass    494
# 711                   711        GourgeistSuper Size       GhostGrass    494
# 719                   719        DiancieMega Diancie        RockFairy    700
# 720                   720         HoopaHoopa Unbound      PsychicDark    680
#
#              HP  Attack  Defense  SpecialAttack  SpecialDefense  Speed
# MyNewIndex
# 3            80     100      123            122             120     80
# 6            78     130      111            130              85    100
# 6            78     104       78            159             115    100
# 9            79     103      120            135             115     78
# 15           65     150       40             15              80    145
# 18           83      80       80            135              80    121
# 65           55      50       65            175              95    150
# 80           95      75      180            130              80     30
# 94           60      65       80            170              95    130
# 115         105     125      100             60             100    100
# 127          65     155      120             65              90    105
# 130          95     155      109             70             130     81
# 142          80     135       85             70              95    150
# 150         126     190      100            154             100    130
# 150         106     150       70            194             120    140
# 181          90      95      105            165             110     45
# 208          75     125      230             55              95     30
# 212          70     150      140             65             100     75
# 214          80     185      115             40             105     75
# 229          75      90       90            140              90    115
# 248         100     164      150             95             120     71
# 254          70     110       75            145              85    145
# 257          80     160       80            130              80    100
# 260         100     150      110             95             110     70
# 282          68      85       65            165             135    100
# 302          50      85      125             85             115     20
# 303          50     105      125             55              95     50
# 306          70     140      230             60              80     50
# 308          60     100       85             80              85    100
# 310          70      75       80            135              80    135
# ...         ...     ...      ...            ...             ...    ...
# 445         108     170      115            120              95     92
# 448          70     145       88            140              70    112
# 460          90     132      105            132             105     30
# 475          68     165       95             65             115    110
# 479          50      65      107            105             107     86
# 479          50      65      107            105             107     86
# 479          50      65      107            105             107     86
# 479          50      65      107            105             107     86
# 479          50      65      107            105             107     86
# 487         150     120      100            120             100     90
# 492         100     103       75            120              75    127
# 531         103      60      126             80             126     50
# 555         105      30      105            140             105     55
# 641          79     100       80            110              90    121
# 642          79     105       70            145              80    101
# 645          89     145       90            105              80     91
# 646         125     170      100            120              90     95
# 646         125     120       90            170             100     95
# 647          91      72       90            129              90    108
# 648         100     128       90             77              77    128
# 678          74      48       76             83              81    104
# 681          60      50      150             50             150     60
# 710          44      66       70             44              55     56
# 710          54      66       70             44              55     46
# 710          59      66       70             44              55     41
# 711          55      85      122             58              75     99
# 711          75      95      122             58              75     69
# 711          85     100      122             58              75     54
# 719          50     160      110            160             110    110
# 720          80     160       60            170             130     80
#
# [79 rows x 10 columns]

# %%
pokedex_file.Name.duplicated().any()
# Out:
# False

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### 8.2 Parse the raw pokedex with list comprehensions
#
# ---
#
# Perform the same parsing as above, but **using only a single list comprehension** instead of for loops. You may have nested list comprehensions within the main list comprehension! The output should be exactly the same.

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 9. Write a function to generate the full pokedex
#
# ---
#
# Write a function that recreates the pokedex you made before, but with the data read in from the full pokemon file. The `PokedexNumber` should be used as the `pokemon_id` key values for the dictionary of pokemon.
#
# Your function should:
#
# 1. Take the parsed pokedex information you created above as an argument.
# 2. Return a dictionary in the same format as your original pokedex you created before containing the information from the parsed full pokedex file.
#
# To test the function, print out the pokemon with id = 100.

# %%
new_pokedex = pokedex_file.T.to_dict()
new_pokedex
# Out:
# {1: {'Attack': 49,
#   'Defense': 49,
#   'HP': 45,
#   'Name': 'Bulbasaur',
#   'PokedexNumber': 1,
#   'SpecialAttack': 65,
#   'SpecialDefense': 65,
#   'Speed': 45,
#   'Total': 318,
#   'Type': 'GrassPoison'},
#  2: {'Attack': 62,
#   'Defense': 63,
#   'HP': 60,
#   'Name': 'Ivysaur',
#   'PokedexNumber': 2,
#   'SpecialAttack': 80,
#   'SpecialDefense': 80,
#   'Speed': 60,
#   'Total': 405,
#   'Type': 'GrassPoison'},
#  3: {'Attack': 100,
#   'Defense': 123,
#   'HP': 80,
#   'Name': 'VenusaurMega Venusaur',
#   'PokedexNumber': 3,
#   'SpecialAttack': 122,
#   'SpecialDefense': 120,
#   'Speed': 80,
#   'Total': 625,
#   'Type': 'GrassPoison'},
#  4: {'Attack': 52,
#   'Defense': 43,
#   'HP': 39,
#   'Name': 'Charmander',
#   'PokedexNumber': 4,
#   'SpecialAttack': 60,
#   'SpecialDefense': 50,
#   'Speed': 65,
#   'Total': 309,
#   'Type': 'Fire'},
#  5: {'Attack': 64,
#   'Defense': 58,
#   'HP': 58,
#   'Name': 'Charmeleon',
#   'PokedexNumber': 5,
#   'SpecialAttack': 80,
#   'SpecialDefense': 65,
#   'Speed': 80,
#   'Total': 405,
#   'Type': 'Fire'},
#  6: {'Attack': 104,
#   'Defense': 78,
#   'HP': 78,
#   'Name': 'CharizardMega Charizard Y',
#   'PokedexNumber': 6,
#   'SpecialAttack': 159,
#   'SpecialDefense': 115,
#   'Speed': 100,
#   'Total': 634,
#   'Type': 'FireFlying'},
#  7: {'Attack': 48,
#   'Defense': 65,
#   'HP': 44,
#   'Name': 'Squirtle',
#   'PokedexNumber': 7,
#   'SpecialAttack': 50,
#   'SpecialDefense': 64,
#   'Speed': 43,
#   'Total': 314,
#   'Type': 'Water'},
#  8: {'Attack': 63,
#   'Defense': 80,
#   'HP': 59,
#   'Name': 'Wartortle',
#   'PokedexNumber': 8,
#   'SpecialAttack': 65,
#   'SpecialDefense': 80,
#   'Speed': 58,
#   'Total': 405,
#   'Type': 'Water'},
#  9: {'Attack': 103,
#   'Defense': 120,
#   'HP': 79,
#   'Name': 'BlastoiseMega Blastoise',
#   'PokedexNumber': 9,
#   'SpecialAttack': 135,
#   'SpecialDefense': 115,
#   'Speed': 78,
#   'Total': 630,
#   'Type': 'Water'},
#  10: {'Attack': 30,
#   'Defense': 35,
#   'HP': 45,
#   'Name': 'Caterpie',
#   'PokedexNumber': 10,
#   'SpecialAttack': 20,
#   'SpecialDefense': 20,
#   'Speed': 45,
#   'Total': 195,
#   'Type': 'Bug'},
#  11: {'Attack': 20,
#   'Defense': 55,
#   'HP': 50,
#   'Name': 'Metapod',
#   'PokedexNumber': 11,
#   'SpecialAttack': 25,
#   'SpecialDefense': 25,
#   'Speed': 30,
#   'Total': 205,
#   'Type': 'Bug'},
#  12: {'Attack': 45,
#   'Defense': 50,
#   'HP': 60,
#   'Name': 'Butterfree',
#   'PokedexNumber': 12,
#   'SpecialAttack': 90,
#   'SpecialDefense': 80,
#   'Speed': 70,
#   'Total': 395,
#   'Type': 'BugFlying'},
#  13: {'Attack': 35,
#   'Defense': 30,
#   'HP': 40,
#   'Name': 'Weedle',
#   'PokedexNumber': 13,
#   'SpecialAttack': 20,
#   'SpecialDefense': 20,
#   'Speed': 50,
#   'Total': 195,
#   'Type': 'BugPoison'},
#  14: {'Attack': 25,
#   'Defense': 50,
#   'HP': 45,
#   'Name': 'Kakuna',
#   'PokedexNumber': 14,
#   'SpecialAttack': 25,
#   'SpecialDefense': 25,
#   'Speed': 35,
#   'Total': 205,
#   'Type': 'BugPoison'},
#  15: {'Attack': 150,
#   'Defense': 40,
#   'HP': 65,
#   'Name': 'BeedrillMega Beedrill',
#   'PokedexNumber': 15,
#   'SpecialAttack': 15,
#   'SpecialDefense': 80,
#   'Speed': 145,
#   'Total': 495,
#   'Type': 'BugPoison'},
#  16: {'Attack': 45,
#   'Defense': 40,
#   'HP': 40,
#   'Name': 'Pidgey',
#   'PokedexNumber': 16,
#   'SpecialAttack': 35,
#   'SpecialDefense': 35,
#   'Speed': 56,
#   'Total': 251,
#   'Type': 'NormalFlying'},
#  17: {'Attack': 60,
#   'Defense': 55,
#   'HP': 63,
#   'Name': 'Pidgeotto',
#   'PokedexNumber': 17,
#   'SpecialAttack': 50,
#   'SpecialDefense': 50,
#   'Speed': 71,
#   'Total': 349,
#   'Type': 'NormalFlying'},
#  18: {'Attack': 80,
#   'Defense': 80,
#   'HP': 83,
#   'Name': 'PidgeotMega Pidgeot',
#   'PokedexNumber': 18,
#   'SpecialAttack': 135,
#   'SpecialDefense': 80,
#   'Speed': 121,
#   'Total': 579,
#   'Type': 'NormalFlying'},
#  19: {'Attack': 56,
#   'Defense': 35,
#   'HP': 30,
#   'Name': 'Rattata',
#   'PokedexNumber': 19,
#   'SpecialAttack': 25,
#   'SpecialDefense': 35,
#   'Speed': 72,
#   'Total': 253,
#   'Type': 'Normal'},
#  20: {'Attack': 81,
#   'Defense': 60,
#   'HP': 55,
#   'Name': 'Raticate',
#   'PokedexNumber': 20,
#   'SpecialAttack': 50,
#   'SpecialDefense': 70,
#   'Speed': 97,
#   'Total': 413,
#   'Type': 'Normal'},
#  21: {'Attack': 60,
#   'Defense': 30,
#   'HP': 40,
#   'Name': 'Spearow',
#   'PokedexNumber': 21,
#   'SpecialAttack': 31,
#   'SpecialDefense': 31,
#   'Speed': 70,
#   'Total': 262,
#   'Type': 'NormalFlying'},
#  22: {'Attack': 90,
#   'Defense': 65,
#   'HP': 65,
#   'Name': 'Fearow',
#   'PokedexNumber': 22,
#   'SpecialAttack': 61,
#   'SpecialDefense': 61,
#   'Speed': 100,
#   'Total': 442,
#   'Type': 'NormalFlying'},
#  23: {'Attack': 60,
#   'Defense': 44,
#   'HP': 35,
#   'Name': 'Ekans',
#   'PokedexNumber': 23,
#   'SpecialAttack': 40,
#   'SpecialDefense': 54,
#   'Speed': 55,
#   'Total': 288,
#   'Type': 'Poison'},
#  24: {'Attack': 85,
#   'Defense': 69,
#   'HP': 60,
#   'Name': 'Arbok',
#   'PokedexNumber': 24,
#   'SpecialAttack': 65,
#   'SpecialDefense': 79,
#   'Speed': 80,
#   'Total': 438,
#   'Type': 'Poison'},
#  25: {'Attack': 55,
#   'Defense': 40,
#   'HP': 35,
#   'Name': 'Pikachu',
#   'PokedexNumber': 25,
#   'SpecialAttack': 50,
#   'SpecialDefense': 50,
#   'Speed': 90,
#   'Total': 320,
#   'Type': 'Electric'},
#  26: {'Attack': 90,
#   'Defense': 55,
#   'HP': 60,
#   'Name': 'Raichu',
#   'PokedexNumber': 26,
#   'SpecialAttack': 90,
#   'SpecialDefense': 80,
#   'Speed': 110,
#   'Total': 485,
#   'Type': 'Electric'},
#  27: {'Attack': 75,
#   'Defense': 85,
#   'HP': 50,
#   'Name': 'Sandshrew',
#   'PokedexNumber': 27,
#   'SpecialAttack': 20,
#   'SpecialDefense': 30,
#   'Speed': 40,
#   'Total': 300,
#   'Type': 'Ground'},
#  28: {'Attack': 100,
#   'Defense': 110,
#   'HP': 75,
#   'Name': 'Sandslash',
#   'PokedexNumber': 28,
#   'SpecialAttack': 45,
#   'SpecialDefense': 55,
#   'Speed': 65,
#   'Total': 450,
#   'Type': 'Ground'},
#  29: {'Attack': 47,
#   'Defense': 52,
#   'HP': 55,
#   'Name': 'NidoranF',
#   'PokedexNumber': 29,
#   'SpecialAttack': 40,
#   'SpecialDefense': 40,
#   'Speed': 41,
#   'Total': 275,
#   'Type': 'Poison'},
#  30: {'Attack': 62,
#   'Defense': 67,
#   'HP': 70,
#   'Name': 'Nidorina',
#   'PokedexNumber': 30,
#   'SpecialAttack': 55,
#   'SpecialDefense': 55,
#   'Speed': 56,
#   'Total': 365,
#   'Type': 'Poison'},
#  31: {'Attack': 92,
#   'Defense': 87,
#   'HP': 90,
#   'Name': 'Nidoqueen',
#   'PokedexNumber': 31,
#   'SpecialAttack': 75,
#   'SpecialDefense': 85,
#   'Speed': 76,
#   'Total': 505,
#   'Type': 'PoisonGround'},
#  32: {'Attack': 57,
#   'Defense': 40,
#   'HP': 46,
#   'Name': 'NidoranM',
#   'PokedexNumber': 32,
#   'SpecialAttack': 40,
#   'SpecialDefense': 40,
#   'Speed': 50,
#   'Total': 273,
#   'Type': 'Poison'},
#  33: {'Attack': 72,
#   'Defense': 57,
#   'HP': 61,
#   'Name': 'Nidorino',
#   'PokedexNumber': 33,
#   'SpecialAttack': 55,
#   'SpecialDefense': 55,
#   'Speed': 65,
#   'Total': 365,
#   'Type': 'Poison'},
#  34: {'Attack': 102,
#   'Defense': 77,
#   'HP': 81,
#   'Name': 'Nidoking',
#   'PokedexNumber': 34,
#   'SpecialAttack': 85,
#   'SpecialDefense': 75,
#   'Speed': 85,
#   'Total': 505,
#   'Type': 'PoisonGround'},
#  35: {'Attack': 45,
#   'Defense': 48,
#   'HP': 70,
#   'Name': 'Clefairy',
#   'PokedexNumber': 35,
#   'SpecialAttack': 60,
#   'SpecialDefense': 65,
#   'Speed': 35,
#   'Total': 323,
#   'Type': 'Fairy'},
#  36: {'Attack': 70,
#   'Defense': 73,
#   'HP': 95,
#   'Name': 'Clefable',
#   'PokedexNumber': 36,
#   'SpecialAttack': 95,
#   'SpecialDefense': 90,
#   'Speed': 60,
#   'Total': 483,
#   'Type': 'Fairy'},
#  37: {'Attack': 41,
#   'Defense': 40,
#   'HP': 38,
#   'Name': 'Vulpix',
#   'PokedexNumber': 37,
#   'SpecialAttack': 50,
#   'SpecialDefense': 65,
#   'Speed': 65,
#   'Total': 299,
#   'Type': 'Fire'},
#  38: {'Attack': 76,
#   'Defense': 75,
#   'HP': 73,
#   'Name': 'Ninetales',
#   'PokedexNumber': 38,
#   'SpecialAttack': 81,
#   'SpecialDefense': 100,
#   'Speed': 100,
#   'Total': 505,
#   'Type': 'Fire'},
#  39: {'Attack': 45,
#   'Defense': 20,
#   'HP': 115,
#   'Name': 'Jigglypuff',
#   'PokedexNumber': 39,
#   'SpecialAttack': 45,
#   'SpecialDefense': 25,
#   'Speed': 20,
#   'Total': 270,
#   'Type': 'NormalFairy'},
#  40: {'Attack': 70,
#   'Defense': 45,
#   'HP': 140,
#   'Name': 'Wigglytuff',
#   'PokedexNumber': 40,
#   'SpecialAttack': 85,
#   'SpecialDefense': 50,
#   'Speed': 45,
#   'Total': 435,
#   'Type': 'NormalFairy'},
#  41: {'Attack': 45,
#   'Defense': 35,
#   'HP': 40,
#   'Name': 'Zubat',
#   'PokedexNumber': 41,
#   'SpecialAttack': 30,
#   'SpecialDefense': 40,
#   'Speed': 55,
#   'Total': 245,
#   'Type': 'PoisonFlying'},
#  42: {'Attack': 80,
#   'Defense': 70,
#   'HP': 75,
#   'Name': 'Golbat',
#   'PokedexNumber': 42,
#   'SpecialAttack': 65,
#   'SpecialDefense': 75,
#   'Speed': 90,
#   'Total': 455,
#   'Type': 'PoisonFlying'},
#  43: {'Attack': 50,
#   'Defense': 55,
#   'HP': 45,
#   'Name': 'Oddish',
#   'PokedexNumber': 43,
#   'SpecialAttack': 75,
#   'SpecialDefense': 65,
#   'Speed': 30,
#   'Total': 320,
#   'Type': 'GrassPoison'},
#  44: {'Attack': 65,
#   'Defense': 70,
#   'HP': 60,
#   'Name': 'Gloom',
#   'PokedexNumber': 44,
#   'SpecialAttack': 85,
#   'SpecialDefense': 75,
#   'Speed': 40,
#   'Total': 395,
#   'Type': 'GrassPoison'},
#  45: {'Attack': 80,
#   'Defense': 85,
#   'HP': 75,
#   'Name': 'Vileplume',
#   'PokedexNumber': 45,
#   'SpecialAttack': 110,
#   'SpecialDefense': 90,
#   'Speed': 50,
#   'Total': 490,
#   'Type': 'GrassPoison'},
#  46: {'Attack': 70,
#   'Defense': 55,
#   'HP': 35,
#   'Name': 'Paras',
#   'PokedexNumber': 46,
#   'SpecialAttack': 45,
#   'SpecialDefense': 55,
#   'Speed': 25,
#   'Total': 285,
#   'Type': 'BugGrass'},
#  47: {'Attack': 95,
#   'Defense': 80,
#   'HP': 60,
#   'Name': 'Parasect',
#   'PokedexNumber': 47,
#   'SpecialAttack': 60,
#   'SpecialDefense': 80,
#   'Speed': 30,
#   'Total': 405,
#   'Type': 'BugGrass'},
#  48: {'Attack': 55,
#   'Defense': 50,
#   'HP': 60,
#   'Name': 'Venonat',
#   'PokedexNumber': 48,
#   'SpecialAttack': 40,
#   'SpecialDefense': 55,
#   'Speed': 45,
#   'Total': 305,
#   'Type': 'BugPoison'},
#  49: {'Attack': 65,
#   'Defense': 60,
#   'HP': 70,
#   'Name': 'Venomoth',
#   'PokedexNumber': 49,
#   'SpecialAttack': 90,
#   'SpecialDefense': 75,
#   'Speed': 90,
#   'Total': 450,
#   'Type': 'BugPoison'},
#  50: {'Attack': 55,
#   'Defense': 25,
#   'HP': 10,
#   'Name': 'Diglett',
#   'PokedexNumber': 50,
#   'SpecialAttack': 35,
#   'SpecialDefense': 45,
#   'Speed': 95,
#   'Total': 265,
#   'Type': 'Ground'},
#  51: {'Attack': 80,
#   'Defense': 50,
#   'HP': 35,
#   'Name': 'Dugtrio',
#   'PokedexNumber': 51,
#   'SpecialAttack': 50,
#   'SpecialDefense': 70,
#   'Speed': 120,
#   'Total': 405,
#   'Type': 'Ground'},
#  52: {'Attack': 45,
#   'Defense': 35,
#   'HP': 40,
#   'Name': 'Meowth',
#   'PokedexNumber': 52,
#   'SpecialAttack': 40,
#   'SpecialDefense': 40,
#   'Speed': 90,
#   'Total': 290,
#   'Type': 'Normal'},
#  53: {'Attack': 70,
#   'Defense': 60,
#   'HP': 65,
#   'Name': 'Persian',
#   'PokedexNumber': 53,
#   'SpecialAttack': 65,
#   'SpecialDefense': 65,
#   'Speed': 115,
#   'Total': 440,
#   'Type': 'Normal'},
#  54: {'Attack': 52,
#   'Defense': 48,
#   'HP': 50,
#   'Name': 'Psyduck',
#   'PokedexNumber': 54,
#   'SpecialAttack': 65,
#   'SpecialDefense': 50,
#   'Speed': 55,
#   'Total': 320,
#   'Type': 'Water'},
#  55: {'Attack': 82,
#   'Defense': 78,
#   'HP': 80,
#   'Name': 'Golduck',
#   'PokedexNumber': 55,
#   'SpecialAttack': 95,
#   'SpecialDefense': 80,
#   'Speed': 85,
#   'Total': 500,
#   'Type': 'Water'},
#  56: {'Attack': 80,
#   'Defense': 35,
#   'HP': 40,
#   'Name': 'Mankey',
#   'PokedexNumber': 56,
#   'SpecialAttack': 35,
#   'SpecialDefense': 45,
#   'Speed': 70,
#   'Total': 305,
#   'Type': 'Fighting'},
#  57: {'Attack': 105,
#   'Defense': 60,
#   'HP': 65,
#   'Name': 'Primeape',
#   'PokedexNumber': 57,
#   'SpecialAttack': 60,
#   'SpecialDefense': 70,
#   'Speed': 95,
#   'Total': 455,
#   'Type': 'Fighting'},
#  58: {'Attack': 70,
#   'Defense': 45,
#   'HP': 55,
#   'Name': 'Growlithe',
#   'PokedexNumber': 58,
#   'SpecialAttack': 70,
#   'SpecialDefense': 50,
#   'Speed': 60,
#   'Total': 350,
#   'Type': 'Fire'},
#  59: {'Attack': 110,
#   'Defense': 80,
#   'HP': 90,
#   'Name': 'Arcanine',
#   'PokedexNumber': 59,
#   'SpecialAttack': 100,
#   'SpecialDefense': 80,
#   'Speed': 95,
#   'Total': 555,
#   'Type': 'Fire'},
#  60: {'Attack': 50,
#   'Defense': 40,
#   'HP': 40,
#   'Name': 'Poliwag',
#   'PokedexNumber': 60,
#   'SpecialAttack': 40,
#   'SpecialDefense': 40,
#   'Speed': 90,
#   'Total': 300,
#   'Type': 'Water'},
#  61: {'Attack': 65,
#   'Defense': 65,
#   'HP': 65,
#   'Name': 'Poliwhirl',
#   'PokedexNumber': 61,
#   'SpecialAttack': 50,
#   'SpecialDefense': 50,
#   'Speed': 90,
#   'Total': 385,
#   'Type': 'Water'},
#  62: {'Attack': 95,
#   'Defense': 95,
#   'HP': 90,
#   'Name': 'Poliwrath',
#   'PokedexNumber': 62,
#   'SpecialAttack': 70,
#   'SpecialDefense': 90,
#   'Speed': 70,
#   'Total': 510,
#   'Type': 'WaterFighting'},
#  63: {'Attack': 20,
#   'Defense': 15,
#   'HP': 25,
#   'Name': 'Abra',
#   'PokedexNumber': 63,
#   'SpecialAttack': 105,
#   'SpecialDefense': 55,
#   'Speed': 90,
#   'Total': 310,
#   'Type': 'Psychic'},
#  64: {'Attack': 35,
#   'Defense': 30,
#   'HP': 40,
#   'Name': 'Kadabra',
#   'PokedexNumber': 64,
#   'SpecialAttack': 120,
#   'SpecialDefense': 70,
#   'Speed': 105,
#   'Total': 400,
#   'Type': 'Psychic'},
#  65: {'Attack': 50,
#   'Defense': 65,
#   'HP': 55,
#   'Name': 'AlakazamMega Alakazam',
#   'PokedexNumber': 65,
#   'SpecialAttack': 175,
#   'SpecialDefense': 95,
#   'Speed': 150,
#   'Total': 590,
#   'Type': 'Psychic'},
#  66: {'Attack': 80,
#   'Defense': 50,
#   'HP': 70,
#   'Name': 'Machop',
#   'PokedexNumber': 66,
#   'SpecialAttack': 35,
#   'SpecialDefense': 35,
#   'Speed': 35,
#   'Total': 305,
#   'Type': 'Fighting'},
#  67: {'Attack': 100,
#   'Defense': 70,
#   'HP': 80,
#   'Name': 'Machoke',
#   'PokedexNumber': 67,
#   'SpecialAttack': 50,
#   'SpecialDefense': 60,
#   'Speed': 45,
#   'Total': 405,
#   'Type': 'Fighting'},
#  68: {'Attack': 130,
#   'Defense': 80,
#   'HP': 90,
#   'Name': 'Machamp',
#   'PokedexNumber': 68,
#   'SpecialAttack': 65,
#   'SpecialDefense': 85,
#   'Speed': 55,
#   'Total': 505,
#   'Type': 'Fighting'},
#  69: {'Attack': 75,
#   'Defense': 35,
#   'HP': 50,
#   'Name': 'Bellsprout',
#   'PokedexNumber': 69,
#   'SpecialAttack': 70,
#   'SpecialDefense': 30,
#   'Speed': 40,
#   'Total': 300,
#   'Type': 'GrassPoison'},
#  70: {'Attack': 90,
#   'Defense': 50,
#   'HP': 65,
#   'Name': 'Weepinbell',
#   'PokedexNumber': 70,
#   'SpecialAttack': 85,
#   'SpecialDefense': 45,
#   'Speed': 55,
#   'Total': 390,
#   'Type': 'GrassPoison'},
#  71: {'Attack': 105,
#   'Defense': 65,
#   'HP': 80,
#   'Name': 'Victreebel',
#   'PokedexNumber': 71,
#   'SpecialAttack': 100,
#   'SpecialDefense': 70,
#   'Speed': 70,
#   'Total': 490,
#   'Type': 'GrassPoison'},
#  72: {'Attack': 40,
#   'Defense': 35,
#   'HP': 40,
#   'Name': 'Tentacool',
#   'PokedexNumber': 72,
#   'SpecialAttack': 50,
#   'SpecialDefense': 100,
#   'Speed': 70,
#   'Total': 335,
#   'Type': 'WaterPoison'},
#  73: {'Attack': 70,
#   'Defense': 65,
#   'HP': 80,
#   'Name': 'Tentacruel',
#   'PokedexNumber': 73,
#   'SpecialAttack': 80,
#   'SpecialDefense': 120,
#   'Speed': 100,
#   'Total': 515,
#   'Type': 'WaterPoison'},
#  74: {'Attack': 80,
#   'Defense': 100,
#   'HP': 40,
#   'Name': 'Geodude',
#   'PokedexNumber': 74,
#   'SpecialAttack': 30,
#   'SpecialDefense': 30,
#   'Speed': 20,
#   'Total': 300,
#   'Type': 'RockGround'},
#  75: {'Attack': 95,
#   'Defense': 115,
#   'HP': 55,
#   'Name': 'Graveler',
#   'PokedexNumber': 75,
#   'SpecialAttack': 45,
#   'SpecialDefense': 45,
#   'Speed': 35,
#   'Total': 390,
#   'Type': 'RockGround'},
#  76: {'Attack': 120,
#   'Defense': 130,
#   'HP': 80,
#   'Name': 'Golem',
#   'PokedexNumber': 76,
#   'SpecialAttack': 55,
#   'SpecialDefense': 65,
#   'Speed': 45,
#   'Total': 495,
#   'Type': 'RockGround'},
#  77: {'Attack': 85,
#   'Defense': 55,
#   'HP': 50,
#   'Name': 'Ponyta',
#   'PokedexNumber': 77,
#   'SpecialAttack': 65,
#   'SpecialDefense': 65,
#   'Speed': 90,
#   'Total': 410,
#   'Type': 'Fire'},
#  78: {'Attack': 100,
#   'Defense': 70,
#   'HP': 65,
#   'Name': 'Rapidash',
#   'PokedexNumber': 78,
#   'SpecialAttack': 80,
#   'SpecialDefense': 80,
#   'Speed': 105,
#   'Total': 500,
#   'Type': 'Fire'},
#  79: {'Attack': 65,
#   'Defense': 65,
#   'HP': 90,
#   'Name': 'Slowpoke',
#   'PokedexNumber': 79,
#   'SpecialAttack': 40,
#   'SpecialDefense': 40,
#   'Speed': 15,
#   'Total': 315,
#   'Type': 'WaterPsychic'},
#  80: {'Attack': 75,
#   'Defense': 180,
#   'HP': 95,
#   'Name': 'SlowbroMega Slowbro',
#   'PokedexNumber': 80,
#   'SpecialAttack': 130,
#   'SpecialDefense': 80,
#   'Speed': 30,
#   'Total': 590,
#   'Type': 'WaterPsychic'},
#  81: {'Attack': 35,
#   'Defense': 70,
#   'HP': 25,
#   'Name': 'Magnemite',
#   'PokedexNumber': 81,
#   'SpecialAttack': 95,
#   'SpecialDefense': 55,
#   'Speed': 45,
#   'Total': 325,
#   'Type': 'ElectricSteel'},
#  82: {'Attack': 60,
#   'Defense': 95,
#   'HP': 50,
#   'Name': 'Magneton',
#   'PokedexNumber': 82,
#   'SpecialAttack': 120,
#   'SpecialDefense': 70,
#   'Speed': 70,
#   'Total': 465,
#   'Type': 'ElectricSteel'},
#  83: {'Attack': 65,
#   'Defense': 55,
#   'HP': 52,
#   'Name': "Farfetch'd",
#   'PokedexNumber': 83,
#   'SpecialAttack': 58,
#   'SpecialDefense': 62,
#   'Speed': 60,
#   'Total': 352,
#   'Type': 'NormalFlying'},
#  84: {'Attack': 85,
#   'Defense': 45,
#   'HP': 35,
#   'Name': 'Doduo',
#   'PokedexNumber': 84,
#   'SpecialAttack': 35,
#   'SpecialDefense': 35,
#   'Speed': 75,
#   'Total': 310,
#   'Type': 'NormalFlying'},
#  85: {'Attack': 110,
#   'Defense': 70,
#   'HP': 60,
#   'Name': 'Dodrio',
#   'PokedexNumber': 85,
#   'SpecialAttack': 60,
#   'SpecialDefense': 60,
#   'Speed': 100,
#   'Total': 460,
#   'Type': 'NormalFlying'},
#  86: {'Attack': 45,
#   'Defense': 55,
#   'HP': 65,
#   'Name': 'Seel',
#   'PokedexNumber': 86,
#   'SpecialAttack': 45,
#   'SpecialDefense': 70,
#   'Speed': 45,
#   'Total': 325,
#   'Type': 'Water'},
#  87: {'Attack': 70,
#   'Defense': 80,
#   'HP': 90,
#   'Name': 'Dewgong',
#   'PokedexNumber': 87,
#   'SpecialAttack': 70,
#   'SpecialDefense': 95,
#   'Speed': 70,
#   'Total': 475,
#   'Type': 'WaterIce'},
#  88: {'Attack': 80,
#   'Defense': 50,
#   'HP': 80,
#   'Name': 'Grimer',
#   'PokedexNumber': 88,
#   'SpecialAttack': 40,
#   'SpecialDefense': 50,
#   'Speed': 25,
#   'Total': 325,
#   'Type': 'Poison'},
#  89: {'Attack': 105,
#   'Defense': 75,
#   'HP': 105,
#   'Name': 'Muk',
#   'PokedexNumber': 89,
#   'SpecialAttack': 65,
#   'SpecialDefense': 100,
#   'Speed': 50,
#   'Total': 500,
#   'Type': 'Poison'},
#  90: {'Attack': 65,
#   'Defense': 100,
#   'HP': 30,
#   'Name': 'Shellder',
#   'PokedexNumber': 90,
#   'SpecialAttack': 45,
#   'SpecialDefense': 25,
#   'Speed': 40,
#   'Total': 305,
#   'Type': 'Water'},
#  91: {'Attack': 95,
#   'Defense': 180,
#   'HP': 50,
#   'Name': 'Cloyster',
#   'PokedexNumber': 91,
#   'SpecialAttack': 85,
#   'SpecialDefense': 45,
#   'Speed': 70,
#   'Total': 525,
#   'Type': 'WaterIce'},
#  92: {'Attack': 35,
#   'Defense': 30,
#   'HP': 30,
#   'Name': 'Gastly',
#   'PokedexNumber': 92,
#   'SpecialAttack': 100,
#   'SpecialDefense': 35,
#   'Speed': 80,
#   'Total': 310,
#   'Type': 'GhostPoison'},
#  93: {'Attack': 50,
#   'Defense': 45,
#   'HP': 45,
#   'Name': 'Haunter',
#   'PokedexNumber': 93,
#   'SpecialAttack': 115,
#   'SpecialDefense': 55,
#   'Speed': 95,
#   'Total': 405,
#   'Type': 'GhostPoison'},
#  94: {'Attack': 65,
#   'Defense': 80,
#   'HP': 60,
#   'Name': 'GengarMega Gengar',
#   'PokedexNumber': 94,
#   'SpecialAttack': 170,
#   'SpecialDefense': 95,
#   'Speed': 130,
#   'Total': 600,
#   'Type': 'GhostPoison'},
#  95: {'Attack': 45,
#   'Defense': 160,
#   'HP': 35,
#   'Name': 'Onix',
#   'PokedexNumber': 95,
#   'SpecialAttack': 30,
#   'SpecialDefense': 45,
#   'Speed': 70,
#   'Total': 385,
#   'Type': 'RockGround'},
#  96: {'Attack': 48,
#   'Defense': 45,
#   'HP': 60,
#   'Name': 'Drowzee',
#   'PokedexNumber': 96,
#   'SpecialAttack': 43,
#   'SpecialDefense': 90,
#   'Speed': 42,
#   'Total': 328,
#   'Type': 'Psychic'},
#  97: {'Attack': 73,
#   'Defense': 70,
#   'HP': 85,
#   'Name': 'Hypno',
#   'PokedexNumber': 97,
#   'SpecialAttack': 73,
#   'SpecialDefense': 115,
#   'Speed': 67,
#   'Total': 483,
#   'Type': 'Psychic'},
#  98: {'Attack': 105,
#   'Defense': 90,
#   'HP': 30,
#   'Name': 'Krabby',
#   'PokedexNumber': 98,
#   'SpecialAttack': 25,
#   'SpecialDefense': 25,
#   'Speed': 50,
#   'Total': 325,
#   'Type': 'Water'},
#  99: {'Attack': 130,
#   'Defense': 115,
#   'HP': 55,
#   'Name': 'Kingler',
#   'PokedexNumber': 99,
#   'SpecialAttack': 50,
#   'SpecialDefense': 50,
#   'Speed': 75,
#   'Total': 475,
#   'Type': 'Water'},
#  100: {'Attack': 30,
#   'Defense': 50,
#   'HP': 40,
#   'Name': 'Voltorb',
#   'PokedexNumber': 100,
#   'SpecialAttack': 55,
#   'SpecialDefense': 55,
#   'Speed': 100,
#   'Total': 330,
#   'Type': 'Electric'},
#  101: {'Attack': 50,
#   'Defense': 70,
#   'HP': 60,
#   'Name': 'Electrode',
#   'PokedexNumber': 101,
#   'SpecialAttack': 80,
#   'SpecialDefense': 80,
#   'Speed': 140,
#   'Total': 480,
#   'Type': 'Electric'},
#  102: {'Attack': 40,
#   'Defense': 80,
#   'HP': 60,
#   'Name': 'Exeggcute',
#   'PokedexNumber': 102,
#   'SpecialAttack': 60,
#   'SpecialDefense': 45,
#   'Speed': 40,
#   'Total': 325,
#   'Type': 'GrassPsychic'},
#  103: {'Attack': 95,
#   'Defense': 85,
#   'HP': 95,
#   'Name': 'Exeggutor',
#   'PokedexNumber': 103,
#   'SpecialAttack': 125,
#   'SpecialDefense': 65,
#   'Speed': 55,
#   'Total': 520,
#   'Type': 'GrassPsychic'},
#  104: {'Attack': 50,
#   'Defense': 95,
#   'HP': 50,
#   'Name': 'Cubone',
#   'PokedexNumber': 104,
#   'SpecialAttack': 40,
#   'SpecialDefense': 50,
#   'Speed': 35,
#   'Total': 320,
#   'Type': 'Ground'},
#  105: {'Attack': 80,
#   'Defense': 110,
#   'HP': 60,
#   'Name': 'Marowak',
#   'PokedexNumber': 105,
#   'SpecialAttack': 50,
#   'SpecialDefense': 80,
#   'Speed': 45,
#   'Total': 425,
#   'Type': 'Ground'},
#  106: {'Attack': 120,
#   'Defense': 53,
#   'HP': 50,
#   'Name': 'Hitmonlee',
#   'PokedexNumber': 106,
#   'SpecialAttack': 35,
#   'SpecialDefense': 110,
#   'Speed': 87,
#   'Total': 455,
#   'Type': 'Fighting'},
#  107: {'Attack': 105,
#   'Defense': 79,
#   'HP': 50,
#   'Name': 'Hitmonchan',
#   'PokedexNumber': 107,
#   'SpecialAttack': 35,
#   'SpecialDefense': 110,
#   'Speed': 76,
#   'Total': 455,
#   'Type': 'Fighting'},
#  108: {'Attack': 55,
#   'Defense': 75,
#   'HP': 90,
#   'Name': 'Lickitung',
#   'PokedexNumber': 108,
#   'SpecialAttack': 60,
#   'SpecialDefense': 75,
#   'Speed': 30,
#   'Total': 385,
#   'Type': 'Normal'},
#  109: {'Attack': 65,
#   'Defense': 95,
#   'HP': 40,
#   'Name': 'Koffing',
#   'PokedexNumber': 109,
#   'SpecialAttack': 60,
#   'SpecialDefense': 45,
#   'Speed': 35,
#   'Total': 340,
#   'Type': 'Poison'},
#  110: {'Attack': 90,
#   'Defense': 120,
#   'HP': 65,
#   'Name': 'Weezing',
#   'PokedexNumber': 110,
#   'SpecialAttack': 85,
#   'SpecialDefense': 70,
#   'Speed': 60,
#   'Total': 490,
#   'Type': 'Poison'},
#  111: {'Attack': 85,
#   'Defense': 95,
#   'HP': 80,
#   'Name': 'Rhyhorn',
#   'PokedexNumber': 111,
#   'SpecialAttack': 30,
#   'SpecialDefense': 30,
#   'Speed': 25,
#   'Total': 345,
#   'Type': 'GroundRock'},
#  112: {'Attack': 130,
#   'Defense': 120,
#   'HP': 105,
#   'Name': 'Rhydon',
#   'PokedexNumber': 112,
#   'SpecialAttack': 45,
#   'SpecialDefense': 45,
#   'Speed': 40,
#   'Total': 485,
#   'Type': 'GroundRock'},
#  113: {'Attack': 5,
#   'Defense': 5,
#   'HP': 250,
#   'Name': 'Chansey',
#   'PokedexNumber': 113,
#   'SpecialAttack': 35,
#   'SpecialDefense': 105,
#   'Speed': 50,
#   'Total': 450,
#   'Type': 'Normal'},
#  114: {'Attack': 55,
#   'Defense': 115,
#   'HP': 65,
#   'Name': 'Tangela',
#   'PokedexNumber': 114,
#   'SpecialAttack': 100,
#   'SpecialDefense': 40,
#   'Speed': 60,
#   'Total': 435,
#   'Type': 'Grass'},
#  115: {'Attack': 125,
#   'Defense': 100,
#   'HP': 105,
#   'Name': 'KangaskhanMega Kangaskhan',
#   'PokedexNumber': 115,
#   'SpecialAttack': 60,
#   'SpecialDefense': 100,
#   'Speed': 100,
#   'Total': 590,
#   'Type': 'Normal'},
#  116: {'Attack': 40,
#   'Defense': 70,
#   'HP': 30,
#   'Name': 'Horsea',
#   'PokedexNumber': 116,
#   'SpecialAttack': 70,
#   'SpecialDefense': 25,
#   'Speed': 60,
#   'Total': 295,
#   'Type': 'Water'},
#  117: {'Attack': 65,
#   'Defense': 95,
#   'HP': 55,
#   'Name': 'Seadra',
#   'PokedexNumber': 117,
#   'SpecialAttack': 95,
#   'SpecialDefense': 45,
#   'Speed': 85,
#   'Total': 440,
#   'Type': 'Water'},
#  118: {'Attack': 67,
#   'Defense': 60,
#   'HP': 45,
#   'Name': 'Goldeen',
#   'PokedexNumber': 118,
#   'SpecialAttack': 35,
#   'SpecialDefense': 50,
#   'Speed': 63,
#   'Total': 320,
#   'Type': 'Water'},
#  119: {'Attack': 92,
#   'Defense': 65,
#   'HP': 80,
#   'Name': 'Seaking',
#   'PokedexNumber': 119,
#   'SpecialAttack': 65,
#   'SpecialDefense': 80,
#   'Speed': 68,
#   'Total': 450,
#   'Type': 'Water'},
#  120: {'Attack': 45,
#   'Defense': 55,
#   'HP': 30,
#   'Name': 'Staryu',
#   'PokedexNumber': 120,
#   'SpecialAttack': 70,
#   'SpecialDefense': 55,
#   'Speed': 85,
#   'Total': 340,
#   'Type': 'Water'},
#  121: {'Attack': 75,
#   'Defense': 85,
#   'HP': 60,
#   'Name': 'Starmie',
#   'PokedexNumber': 121,
#   'SpecialAttack': 100,
#   'SpecialDefense': 85,
#   'Speed': 115,
#   'Total': 520,
#   'Type': 'WaterPsychic'},
#  122: {'Attack': 45,
#   'Defense': 65,
#   'HP': 40,
#   'Name': 'Mr. Mime',
#   'PokedexNumber': 122,
#   'SpecialAttack': 100,
#   'SpecialDefense': 120,
#   'Speed': 90,
#   'Total': 460,
#   'Type': 'PsychicFairy'},
#  123: {'Attack': 110,
#   'Defense': 80,
#   'HP': 70,
#   'Name': 'Scyther',
#   'PokedexNumber': 123,
#   'SpecialAttack': 55,
#   'SpecialDefense': 80,
#   'Speed': 105,
#   'Total': 500,
#   'Type': 'BugFlying'},
#  124: {'Attack': 50,
#   'Defense': 35,
#   'HP': 65,
#   'Name': 'Jynx',
#   'PokedexNumber': 124,
#   'SpecialAttack': 115,
#   'SpecialDefense': 95,
#   'Speed': 95,
#   'Total': 455,
#   'Type': 'IcePsychic'},
#  125: {'Attack': 83,
#   'Defense': 57,
#   'HP': 65,
#   'Name': 'Electabuzz',
#   'PokedexNumber': 125,
#   'SpecialAttack': 95,
#   'SpecialDefense': 85,
#   'Speed': 105,
#   'Total': 490,
#   'Type': 'Electric'},
#  126: {'Attack': 95,
#   'Defense': 57,
#   'HP': 65,
#   'Name': 'Magmar',
#   'PokedexNumber': 126,
#   'SpecialAttack': 100,
#   'SpecialDefense': 85,
#   'Speed': 93,
#   'Total': 495,
#   'Type': 'Fire'},
#  127: {'Attack': 155,
#   'Defense': 120,
#   'HP': 65,
#   'Name': 'PinsirMega Pinsir',
#   'PokedexNumber': 127,
#   'SpecialAttack': 65,
#   'SpecialDefense': 90,
#   'Speed': 105,
#   'Total': 600,
#   'Type': 'BugFlying'},
#  128: {'Attack': 100,
#   'Defense': 95,
#   'HP': 75,
#   'Name': 'Tauros',
#   'PokedexNumber': 128,
#   'SpecialAttack': 40,
#   'SpecialDefense': 70,
#   'Speed': 110,
#   'Total': 490,
#   'Type': 'Normal'},
#  129: {'Attack': 10,
#   'Defense': 55,
#   'HP': 20,
#   'Name': 'Magikarp',
#   'PokedexNumber': 129,
#   'SpecialAttack': 15,
#   'SpecialDefense': 20,
#   'Speed': 80,
#   'Total': 200,
#   'Type': 'Water'},
#  130: {'Attack': 155,
#   'Defense': 109,
#   'HP': 95,
#   'Name': 'GyaradosMega Gyarados',
#   'PokedexNumber': 130,
#   'SpecialAttack': 70,
#   'SpecialDefense': 130,
#   'Speed': 81,
#   'Total': 640,
#   'Type': 'WaterDark'},
#  131: {'Attack': 85,
#   'Defense': 80,
#   'HP': 130,
#   'Name': 'Lapras',
#   'PokedexNumber': 131,
#   'SpecialAttack': 85,
#   'SpecialDefense': 95,
#   'Speed': 60,
#   'Total': 535,
#   'Type': 'WaterIce'},
#  132: {'Attack': 48,
#   'Defense': 48,
#   'HP': 48,
#   'Name': 'Ditto',
#   'PokedexNumber': 132,
#   'SpecialAttack': 48,
#   'SpecialDefense': 48,
#   'Speed': 48,
#   'Total': 288,
#   'Type': 'Normal'},
#  133: {'Attack': 55,
#   'Defense': 50,
#   'HP': 55,
#   'Name': 'Eevee',
#   'PokedexNumber': 133,
#   'SpecialAttack': 45,
#   'SpecialDefense': 65,
#   'Speed': 55,
#   'Total': 325,
#   'Type': 'Normal'},
#  134: {'Attack': 65,
#   'Defense': 60,
#   'HP': 130,
#   'Name': 'Vaporeon',
#   'PokedexNumber': 134,
#   'SpecialAttack': 110,
#   'SpecialDefense': 95,
#   'Speed': 65,
#   'Total': 525,
#   'Type': 'Water'},
#  135: {'Attack': 65,
#   'Defense': 60,
#   'HP': 65,
#   'Name': 'Jolteon',
#   'PokedexNumber': 135,
#   'SpecialAttack': 110,
#   'SpecialDefense': 95,
#   'Speed': 130,
#   'Total': 525,
#   'Type': 'Electric'},
#  136: {'Attack': 130,
#   'Defense': 60,
#   'HP': 65,
#   'Name': 'Flareon',
#   'PokedexNumber': 136,
#   'SpecialAttack': 95,
#   'SpecialDefense': 110,
#   'Speed': 65,
#   'Total': 525,
#   'Type': 'Fire'},
#  137: {'Attack': 60,
#   'Defense': 70,
#   'HP': 65,
#   'Name': 'Porygon',
#   'PokedexNumber': 137,
#   'SpecialAttack': 85,
#   'SpecialDefense': 75,
#   'Speed': 40,
#   'Total': 395,
#   'Type': 'Normal'},
#  138: {'Attack': 40,
#   'Defense': 100,
#   'HP': 35,
#   'Name': 'Omanyte',
#   'PokedexNumber': 138,
#   'SpecialAttack': 90,
#   'SpecialDefense': 55,
#   'Speed': 35,
#   'Total': 355,
#   'Type': 'RockWater'},
#  139: {'Attack': 60,
#   'Defense': 125,
#   'HP': 70,
#   'Name': 'Omastar',
#   'PokedexNumber': 139,
#   'SpecialAttack': 115,
#   'SpecialDefense': 70,
#   'Speed': 55,
#   'Total': 495,
#   'Type': 'RockWater'},
#  140: {'Attack': 80,
#   'Defense': 90,
#   'HP': 30,
#   'Name': 'Kabuto',
#   'PokedexNumber': 140,
#   'SpecialAttack': 55,
#   'SpecialDefense': 45,
#   'Speed': 55,
#   'Total': 355,
#   'Type': 'RockWater'},
#  141: {'Attack': 115,
#   'Defense': 105,
#   'HP': 60,
#   'Name': 'Kabutops',
#   'PokedexNumber': 141,
#   'SpecialAttack': 65,
#   'SpecialDefense': 70,
#   'Speed': 80,
#   'Total': 495,
#   'Type': 'RockWater'},
#  142: {'Attack': 135,
#   'Defense': 85,
#   'HP': 80,
#   'Name': 'AerodactylMega Aerodactyl',
#   'PokedexNumber': 142,
#   'SpecialAttack': 70,
#   'SpecialDefense': 95,
#   'Speed': 150,
#   'Total': 615,
#   'Type': 'RockFlying'},
#  143: {'Attack': 110,
#   'Defense': 65,
#   'HP': 160,
#   'Name': 'Snorlax',
#   'PokedexNumber': 143,
#   'SpecialAttack': 65,
#   'SpecialDefense': 110,
#   'Speed': 30,
#   'Total': 540,
#   'Type': 'Normal'},
#  144: {'Attack': 85,
#   'Defense': 100,
#   'HP': 90,
#   'Name': 'Articuno',
#   'PokedexNumber': 144,
#   'SpecialAttack': 95,
#   'SpecialDefense': 125,
#   'Speed': 85,
#   'Total': 580,
#   'Type': 'IceFlying'},
#  145: {'Attack': 90,
#   'Defense': 85,
#   'HP': 90,
#   'Name': 'Zapdos',
#   'PokedexNumber': 145,
#   'SpecialAttack': 125,
#   'SpecialDefense': 90,
#   'Speed': 100,
#   'Total': 580,
#   'Type': 'ElectricFlying'},
#  146: {'Attack': 100,
#   'Defense': 90,
#   'HP': 90,
#   'Name': 'Moltres',
#   'PokedexNumber': 146,
#   'SpecialAttack': 125,
#   'SpecialDefense': 85,
#   'Speed': 90,
#   'Total': 580,
#   'Type': 'FireFlying'},
#  147: {'Attack': 64,
#   'Defense': 45,
#   'HP': 41,
#   'Name': 'Dratini',
#   'PokedexNumber': 147,
#   'SpecialAttack': 50,
#   'SpecialDefense': 50,
#   'Speed': 50,
#   'Total': 300,
#   'Type': 'Dragon'},
#  148: {'Attack': 84,
#   'Defense': 65,
#   'HP': 61,
#   'Name': 'Dragonair',
#   'PokedexNumber': 148,
#   'SpecialAttack': 70,
#   'SpecialDefense': 70,
#   'Speed': 70,
#   'Total': 420,
#   'Type': 'Dragon'},
#  149: {'Attack': 134,
#   'Defense': 95,
#   'HP': 91,
#   'Name': 'Dragonite',
#   'PokedexNumber': 149,
#   'SpecialAttack': 100,
#   'SpecialDefense': 100,
#   'Speed': 80,
#   'Total': 600,
#   'Type': 'DragonFlying'},
#  150: {'Attack': 150,
#   'Defense': 70,
#   'HP': 106,
#   'Name': 'MewtwoMega Mewtwo Y',
#   'PokedexNumber': 150,
#   'SpecialAttack': 194,
#   'SpecialDefense': 120,
#   'Speed': 140,
#   'Total': 780,
#   'Type': 'Psychic'},
#  151: {'Attack': 100,
#   'Defense': 100,
#   'HP': 100,
#   'Name': 'Mew',
#   'PokedexNumber': 151,
#   'SpecialAttack': 100,
#   'SpecialDefense': 100,
#   'Speed': 100,
#   'Total': 600,
#   'Type': 'Psychic'},
#  152: {'Attack': 49,
#   'Defense': 65,
#   'HP': 45,
#   'Name': 'Chikorita',
#   'PokedexNumber': 152,
#   'SpecialAttack': 49,
#   'SpecialDefense': 65,
#   'Speed': 45,
#   'Total': 318,
#   'Type': 'Grass'},
#  153: {'Attack': 62,
#   'Defense': 80,
#   'HP': 60,
#   'Name': 'Bayleef',
#   'PokedexNumber': 153,
#   'SpecialAttack': 63,
#   'SpecialDefense': 80,
#   'Speed': 60,
#   'Total': 405,
#   'Type': 'Grass'},
#  154: {'Attack': 82,
#   'Defense': 100,
#   'HP': 80,
#   'Name': 'Meganium',
#   'PokedexNumber': 154,
#   'SpecialAttack': 83,
#   'SpecialDefense': 100,
#   'Speed': 80,
#   'Total': 525,
#   'Type': 'Grass'},
#  155: {'Attack': 52,
#   'Defense': 43,
#   'HP': 39,
#   'Name': 'Cyndaquil',
#   'PokedexNumber': 155,
#   'SpecialAttack': 60,
#   'SpecialDefense': 50,
#   'Speed': 65,
#   'Total': 309,
#   'Type': 'Fire'},
#  156: {'Attack': 64,
#   'Defense': 58,
#   'HP': 58,
#   'Name': 'Quilava',
#   'PokedexNumber': 156,
#   'SpecialAttack': 80,
#   'SpecialDefense': 65,
#   'Speed': 80,
#   'Total': 405,
#   'Type': 'Fire'},
#  157: {'Attack': 84,
#   'Defense': 78,
#   'HP': 78,
#   'Name': 'Typhlosion',
#   'PokedexNumber': 157,
#   'SpecialAttack': 109,
#   'SpecialDefense': 85,
#   'Speed': 100,
#   'Total': 534,
#   'Type': 'Fire'},
#  158: {'Attack': 65,
#   'Defense': 64,
#   'HP': 50,
#   'Name': 'Totodile',
#   'PokedexNumber': 158,
#   'SpecialAttack': 44,
#   'SpecialDefense': 48,
#   'Speed': 43,
#   'Total': 314,
#   'Type': 'Water'},
#  159: {'Attack': 80,
#   'Defense': 80,
#   'HP': 65,
#   'Name': 'Croconaw',
#   'PokedexNumber': 159,
#   'SpecialAttack': 59,
#   'SpecialDefense': 63,
#   'Speed': 58,
#   'Total': 405,
#   'Type': 'Water'},
#  160: {'Attack': 105,
#   'Defense': 100,
#   'HP': 85,
#   'Name': 'Feraligatr',
#   'PokedexNumber': 160,
#   'SpecialAttack': 79,
#   'SpecialDefense': 83,
#   'Speed': 78,
#   'Total': 530,
#   'Type': 'Water'},
#  161: {'Attack': 46,
#   'Defense': 34,
#   'HP': 35,
#   'Name': 'Sentret',
#   'PokedexNumber': 161,
#   'SpecialAttack': 35,
#   'SpecialDefense': 45,
#   'Speed': 20,
#   'Total': 215,
#   'Type': 'Normal'},
#  162: {'Attack': 76,
#   'Defense': 64,
#   'HP': 85,
#   'Name': 'Furret',
#   'PokedexNumber': 162,
#   'SpecialAttack': 45,
#   'SpecialDefense': 55,
#   'Speed': 90,
#   'Total': 415,
#   'Type': 'Normal'},
#  163: {'Attack': 30,
#   'Defense': 30,
#   'HP': 60,
#   'Name': 'Hoothoot',
#   'PokedexNumber': 163,
#   'SpecialAttack': 36,
#   'SpecialDefense': 56,
#   'Speed': 50,
#   'Total': 262,
#   'Type': 'NormalFlying'},
#  164: {'Attack': 50,
#   'Defense': 50,
#   'HP': 100,
#   'Name': 'Noctowl',
#   'PokedexNumber': 164,
#   'SpecialAttack': 76,
#   'SpecialDefense': 96,
#   'Speed': 70,
#   'Total': 442,
#   'Type': 'NormalFlying'},
#  165: {'Attack': 20,
#   'Defense': 30,
#   'HP': 40,
#   'Name': 'Ledyba',
#   'PokedexNumber': 165,
#   'SpecialAttack': 40,
#   'SpecialDefense': 80,
#   'Speed': 55,
#   'Total': 265,
#   'Type': 'BugFlying'},
#  166: {'Attack': 35,
#   'Defense': 50,
#   'HP': 55,
#   'Name': 'Ledian',
#   'PokedexNumber': 166,
#   'SpecialAttack': 55,
#   'SpecialDefense': 110,
#   'Speed': 85,
#   'Total': 390,
#   'Type': 'BugFlying'},
#  167: {'Attack': 60,
#   'Defense': 40,
#   'HP': 40,
#   'Name': 'Spinarak',
#   'PokedexNumber': 167,
#   'SpecialAttack': 40,
#   'SpecialDefense': 40,
#   'Speed': 30,
#   'Total': 250,
#   'Type': 'BugPoison'},
#  168: {'Attack': 90,
#   'Defense': 70,
#   'HP': 70,
#   'Name': 'Ariados',
#   'PokedexNumber': 168,
#   'SpecialAttack': 60,
#   'SpecialDefense': 60,
#   'Speed': 40,
#   'Total': 390,
#   'Type': 'BugPoison'},
#  169: {'Attack': 90,
#   'Defense': 80,
#   'HP': 85,
#   'Name': 'Crobat',
#   'PokedexNumber': 169,
#   'SpecialAttack': 70,
#   'SpecialDefense': 80,
#   'Speed': 130,
#   'Total': 535,
#   'Type': 'PoisonFlying'},
#  170: {'Attack': 38,
#   'Defense': 38,
#   'HP': 75,
#   'Name': 'Chinchou',
#   'PokedexNumber': 170,
#   'SpecialAttack': 56,
#   'SpecialDefense': 56,
#   'Speed': 67,
#   'Total': 330,
#   'Type': 'WaterElectric'},
#  171: {'Attack': 58,
#   'Defense': 58,
#   'HP': 125,
#   'Name': 'Lanturn',
#   'PokedexNumber': 171,
#   'SpecialAttack': 76,
#   'SpecialDefense': 76,
#   'Speed': 67,
#   'Total': 460,
#   'Type': 'WaterElectric'},
#  172: {'Attack': 40,
#   'Defense': 15,
#   'HP': 20,
#   'Name': 'Pichu',
#   'PokedexNumber': 172,
#   'SpecialAttack': 35,
#   'SpecialDefense': 35,
#   'Speed': 60,
#   'Total': 205,
#   'Type': 'Electric'},
#  173: {'Attack': 25,
#   'Defense': 28,
#   'HP': 50,
#   'Name': 'Cleffa',
#   'PokedexNumber': 173,
#   'SpecialAttack': 45,
#   'SpecialDefense': 55,
#   'Speed': 15,
#   'Total': 218,
#   'Type': 'Fairy'},
#  174: {'Attack': 30,
#   'Defense': 15,
#   'HP': 90,
#   'Name': 'Igglybuff',
#   'PokedexNumber': 174,
#   'SpecialAttack': 40,
#   'SpecialDefense': 20,
#   'Speed': 15,
#   'Total': 210,
#   'Type': 'NormalFairy'},
#  175: {'Attack': 20,
#   'Defense': 65,
#   'HP': 35,
#   'Name': 'Togepi',
#   'PokedexNumber': 175,
#   'SpecialAttack': 40,
#   'SpecialDefense': 65,
#   'Speed': 20,
#   'Total': 245,
#   'Type': 'Fairy'},
#  176: {'Attack': 40,
#   'Defense': 85,
#   'HP': 55,
#   'Name': 'Togetic',
#   'PokedexNumber': 176,
#   'SpecialAttack': 80,
#   'SpecialDefense': 105,
#   'Speed': 40,
#   'Total': 405,
#   'Type': 'FairyFlying'},
#  177: {'Attack': 50,
#   'Defense': 45,
#   'HP': 40,
#   'Name': 'Natu',
#   'PokedexNumber': 177,
#   'SpecialAttack': 70,
#   'SpecialDefense': 45,
#   'Speed': 70,
#   'Total': 320,
#   'Type': 'PsychicFlying'},
#  178: {'Attack': 75,
#   'Defense': 70,
#   'HP': 65,
#   'Name': 'Xatu',
#   'PokedexNumber': 178,
#   'SpecialAttack': 95,
#   'SpecialDefense': 70,
#   'Speed': 95,
#   'Total': 470,
#   'Type': 'PsychicFlying'},
#  179: {'Attack': 40,
#   'Defense': 40,
#   'HP': 55,
#   'Name': 'Mareep',
#   'PokedexNumber': 179,
#   'SpecialAttack': 65,
#   'SpecialDefense': 45,
#   'Speed': 35,
#   'Total': 280,
#   'Type': 'Electric'},
#  180: {'Attack': 55,
#   'Defense': 55,
#   'HP': 70,
#   'Name': 'Flaaffy',
#   'PokedexNumber': 180,
#   'SpecialAttack': 80,
#   'SpecialDefense': 60,
#   'Speed': 45,
#   'Total': 365,
#   'Type': 'Electric'},
#  181: {'Attack': 95,
#   'Defense': 105,
#   'HP': 90,
#   'Name': 'AmpharosMega Ampharos',
#   'PokedexNumber': 181,
#   'SpecialAttack': 165,
#   'SpecialDefense': 110,
#   'Speed': 45,
#   'Total': 610,
#   'Type': 'ElectricDragon'},
#  182: {'Attack': 80,
#   'Defense': 95,
#   'HP': 75,
#   'Name': 'Bellossom',
#   'PokedexNumber': 182,
#   'SpecialAttack': 90,
#   'SpecialDefense': 100,
#   'Speed': 50,
#   'Total': 490,
#   'Type': 'Grass'},
#  183: {'Attack': 20,
#   'Defense': 50,
#   'HP': 70,
#   'Name': 'Marill',
#   'PokedexNumber': 183,
#   'SpecialAttack': 20,
#   'SpecialDefense': 50,
#   'Speed': 40,
#   'Total': 250,
#   'Type': 'WaterFairy'},
#  184: {'Attack': 50,
#   'Defense': 80,
#   'HP': 100,
#   'Name': 'Azumarill',
#   'PokedexNumber': 184,
#   'SpecialAttack': 60,
#   'SpecialDefense': 80,
#   'Speed': 50,
#   'Total': 420,
#   'Type': 'WaterFairy'},
#  185: {'Attack': 100,
#   'Defense': 115,
#   'HP': 70,
#   'Name': 'Sudowoodo',
#   'PokedexNumber': 185,
#   'SpecialAttack': 30,
#   'SpecialDefense': 65,
#   'Speed': 30,
#   'Total': 410,
#   'Type': 'Rock'},
#  186: {'Attack': 75,
#   'Defense': 75,
#   'HP': 90,
#   'Name': 'Politoed',
#   'PokedexNumber': 186,
#   'SpecialAttack': 90,
#   'SpecialDefense': 100,
#   'Speed': 70,
#   'Total': 500,
#   'Type': 'Water'},
#  187: {'Attack': 35,
#   'Defense': 40,
#   'HP': 35,
#   'Name': 'Hoppip',
#   'PokedexNumber': 187,
#   'SpecialAttack': 35,
#   'SpecialDefense': 55,
#   'Speed': 50,
#   'Total': 250,
#   'Type': 'GrassFlying'},
#  188: {'Attack': 45,
#   'Defense': 50,
#   'HP': 55,
#   'Name': 'Skiploom',
#   'PokedexNumber': 188,
#   'SpecialAttack': 45,
#   'SpecialDefense': 65,
#   'Speed': 80,
#   'Total': 340,
#   'Type': 'GrassFlying'},
#  189: {'Attack': 55,
#   'Defense': 70,
#   'HP': 75,
#   'Name': 'Jumpluff',
#   'PokedexNumber': 189,
#   'SpecialAttack': 55,
#   'SpecialDefense': 95,
#   'Speed': 110,
#   'Total': 460,
#   'Type': 'GrassFlying'},
#  190: {'Attack': 70,
#   'Defense': 55,
#   'HP': 55,
#   'Name': 'Aipom',
#   'PokedexNumber': 190,
#   'SpecialAttack': 40,
#   'SpecialDefense': 55,
#   'Speed': 85,
#   'Total': 360,
#   'Type': 'Normal'},
#  191: {'Attack': 30,
#   'Defense': 30,
#   'HP': 30,
#   'Name': 'Sunkern',
#   'PokedexNumber': 191,
#   'SpecialAttack': 30,
#   'SpecialDefense': 30,
#   'Speed': 30,
#   'Total': 180,
#   'Type': 'Grass'},
#  192: {'Attack': 75,
#   'Defense': 55,
#   'HP': 75,
#   'Name': 'Sunflora',
#   'PokedexNumber': 192,
#   'SpecialAttack': 105,
#   'SpecialDefense': 85,
#   'Speed': 30,
#   'Total': 425,
#   'Type': 'Grass'},
#  193: {'Attack': 65,
#   'Defense': 45,
#   'HP': 65,
#   'Name': 'Yanma',
#   'PokedexNumber': 193,
#   'SpecialAttack': 75,
#   'SpecialDefense': 45,
#   'Speed': 95,
#   'Total': 390,
#   'Type': 'BugFlying'},
#  194: {'Attack': 45,
#   'Defense': 45,
#   'HP': 55,
#   'Name': 'Wooper',
#   'PokedexNumber': 194,
#   'SpecialAttack': 25,
#   'SpecialDefense': 25,
#   'Speed': 15,
#   'Total': 210,
#   'Type': 'WaterGround'},
#  195: {'Attack': 85,
#   'Defense': 85,
#   'HP': 95,
#   'Name': 'Quagsire',
#   'PokedexNumber': 195,
#   'SpecialAttack': 65,
#   'SpecialDefense': 65,
#   'Speed': 35,
#   'Total': 430,
#   'Type': 'WaterGround'},
#  196: {'Attack': 65,
#   'Defense': 60,
#   'HP': 65,
#   'Name': 'Espeon',
#   'PokedexNumber': 196,
#   'SpecialAttack': 130,
#   'SpecialDefense': 95,
#   'Speed': 110,
#   'Total': 525,
#   'Type': 'Psychic'},
#  197: {'Attack': 65,
#   'Defense': 110,
#   'HP': 95,
#   'Name': 'Umbreon',
#   'PokedexNumber': 197,
#   'SpecialAttack': 60,
#   'SpecialDefense': 130,
#   'Speed': 65,
#   'Total': 525,
#   'Type': 'Dark'},
#  198: {'Attack': 85,
#   'Defense': 42,
#   'HP': 60,
#   'Name': 'Murkrow',
#   'PokedexNumber': 198,
#   'SpecialAttack': 85,
#   'SpecialDefense': 42,
#   'Speed': 91,
#   'Total': 405,
#   'Type': 'DarkFlying'},
#  199: {'Attack': 75,
#   'Defense': 80,
#   'HP': 95,
#   'Name': 'Slowking',
#   'PokedexNumber': 199,
#   'SpecialAttack': 100,
#   'SpecialDefense': 110,
#   'Speed': 30,
#   'Total': 490,
#   'Type': 'WaterPsychic'},
#  200: {'Attack': 60,
#   'Defense': 60,
#   'HP': 60,
#   'Name': 'Misdreavus',
#   'PokedexNumber': 200,
#   'SpecialAttack': 85,
#   'SpecialDefense': 85,
#   'Speed': 85,
#   'Total': 435,
#   'Type': 'Ghost'},
#  201: {'Attack': 72,
#   'Defense': 48,
#   'HP': 48,
#   'Name': 'Unown',
#   'PokedexNumber': 201,
#   'SpecialAttack': 72,
#   'SpecialDefense': 48,
#   'Speed': 48,
#   'Total': 336,
#   'Type': 'Psychic'},
#  202: {'Attack': 33,
#   'Defense': 58,
#   'HP': 190,
#   'Name': 'Wobbuffet',
#   'PokedexNumber': 202,
#   'SpecialAttack': 33,
#   'SpecialDefense': 58,
#   'Speed': 33,
#   'Total': 405,
#   'Type': 'Psychic'},
#  203: {'Attack': 80,
#   'Defense': 65,
#   'HP': 70,
#   'Name': 'Girafarig',
#   'PokedexNumber': 203,
#   'SpecialAttack': 90,
#   'SpecialDefense': 65,
#   'Speed': 85,
#   'Total': 455,
#   'Type': 'NormalPsychic'},
#  204: {'Attack': 65,
#   'Defense': 90,
#   'HP': 50,
#   'Name': 'Pineco',
#   'PokedexNumber': 204,
#   'SpecialAttack': 35,
#   'SpecialDefense': 35,
#   'Speed': 15,
#   'Total': 290,
#   'Type': 'Bug'},
#  205: {'Attack': 90,
#   'Defense': 140,
#   'HP': 75,
#   'Name': 'Forretress',
#   'PokedexNumber': 205,
#   'SpecialAttack': 60,
#   'SpecialDefense': 60,
#   'Speed': 40,
#   'Total': 465,
#   'Type': 'BugSteel'},
#  206: {'Attack': 70,
#   'Defense': 70,
#   'HP': 100,
#   'Name': 'Dunsparce',
#   'PokedexNumber': 206,
#   'SpecialAttack': 65,
#   'SpecialDefense': 65,
#   'Speed': 45,
#   'Total': 415,
#   'Type': 'Normal'},
#  207: {'Attack': 75,
#   'Defense': 105,
#   'HP': 65,
#   'Name': 'Gligar',
#   'PokedexNumber': 207,
#   'SpecialAttack': 35,
#   'SpecialDefense': 65,
#   'Speed': 85,
#   'Total': 430,
#   'Type': 'GroundFlying'},
#  208: {'Attack': 125,
#   'Defense': 230,
#   'HP': 75,
#   'Name': 'SteelixMega Steelix',
#   'PokedexNumber': 208,
#   'SpecialAttack': 55,
#   'SpecialDefense': 95,
#   'Speed': 30,
#   'Total': 610,
#   'Type': 'SteelGround'},
#  209: {'Attack': 80,
#   'Defense': 50,
#   'HP': 60,
#   'Name': 'Snubbull',
#   'PokedexNumber': 209,
#   'SpecialAttack': 40,
#   'SpecialDefense': 40,
#   'Speed': 30,
#   'Total': 300,
#   'Type': 'Fairy'},
#  210: {'Attack': 120,
#   'Defense': 75,
#   'HP': 90,
#   'Name': 'Granbull',
#   'PokedexNumber': 210,
#   'SpecialAttack': 60,
#   'SpecialDefense': 60,
#   'Speed': 45,
#   'Total': 450,
#   'Type': 'Fairy'},
#  211: {'Attack': 95,
#   'Defense': 75,
#   'HP': 65,
#   'Name': 'Qwilfish',
#   'PokedexNumber': 211,
#   'SpecialAttack': 55,
#   'SpecialDefense': 55,
#   'Speed': 85,
#   'Total': 430,
#   'Type': 'WaterPoison'},
#  212: {'Attack': 150,
#   'Defense': 140,
#   'HP': 70,
#   'Name': 'ScizorMega Scizor',
#   'PokedexNumber': 212,
#   'SpecialAttack': 65,
#   'SpecialDefense': 100,
#   'Speed': 75,
#   'Total': 600,
#   'Type': 'BugSteel'},
#  213: {'Attack': 10,
#   'Defense': 230,
#   'HP': 20,
#   'Name': 'Shuckle',
#   'PokedexNumber': 213,
#   'SpecialAttack': 10,
#   'SpecialDefense': 230,
#   'Speed': 5,
#   'Total': 505,
#   'Type': 'BugRock'},
#  214: {'Attack': 185,
#   'Defense': 115,
#   'HP': 80,
#   'Name': 'HeracrossMega Heracross',
#   'PokedexNumber': 214,
#   'SpecialAttack': 40,
#   'SpecialDefense': 105,
#   'Speed': 75,
#   'Total': 600,
#   'Type': 'BugFighting'},
#  215: {'Attack': 95,
#   'Defense': 55,
#   'HP': 55,
#   'Name': 'Sneasel',
#   'PokedexNumber': 215,
#   'SpecialAttack': 35,
#   'SpecialDefense': 75,
#   'Speed': 115,
#   'Total': 430,
#   'Type': 'DarkIce'},
#  216: {'Attack': 80,
#   'Defense': 50,
#   'HP': 60,
#   'Name': 'Teddiursa',
#   'PokedexNumber': 216,
#   'SpecialAttack': 50,
#   'SpecialDefense': 50,
#   'Speed': 40,
#   'Total': 330,
#   'Type': 'Normal'},
#  217: {'Attack': 130,
#   'Defense': 75,
#   'HP': 90,
#   'Name': 'Ursaring',
#   'PokedexNumber': 217,
#   'SpecialAttack': 75,
#   'SpecialDefense': 75,
#   'Speed': 55,
#   'Total': 500,
#   'Type': 'Normal'},
#  218: {'Attack': 40,
#   'Defense': 40,
#   'HP': 40,
#   'Name': 'Slugma',
#   'PokedexNumber': 218,
#   'SpecialAttack': 70,
#   'SpecialDefense': 40,
#   'Speed': 20,
#   'Total': 250,
#   'Type': 'Fire'},
#  219: {'Attack': 50,
#   'Defense': 120,
#   'HP': 50,
#   'Name': 'Magcargo',
#   'PokedexNumber': 219,
#   'SpecialAttack': 80,
#   'SpecialDefense': 80,
#   'Speed': 30,
#   'Total': 410,
#   'Type': 'FireRock'},
#  220: {'Attack': 50,
#   'Defense': 40,
#   'HP': 50,
#   'Name': 'Swinub',
#   'PokedexNumber': 220,
#   'SpecialAttack': 30,
#   'SpecialDefense': 30,
#   'Speed': 50,
#   'Total': 250,
#   'Type': 'IceGround'},
#  221: {'Attack': 100,
#   'Defense': 80,
#   'HP': 100,
#   'Name': 'Piloswine',
#   'PokedexNumber': 221,
#   'SpecialAttack': 60,
#   'SpecialDefense': 60,
#   'Speed': 50,
#   'Total': 450,
#   'Type': 'IceGround'},
#  222: {'Attack': 55,
#   'Defense': 85,
#   'HP': 55,
#   'Name': 'Corsola',
#   'PokedexNumber': 222,
#   'SpecialAttack': 65,
#   'SpecialDefense': 85,
#   'Speed': 35,
#   'Total': 380,
#   'Type': 'WaterRock'},
#  223: {'Attack': 65,
#   'Defense': 35,
#   'HP': 35,
#   'Name': 'Remoraid',
#   'PokedexNumber': 223,
#   'SpecialAttack': 65,
#   'SpecialDefense': 35,
#   'Speed': 65,
#   'Total': 300,
#   'Type': 'Water'},
#  224: {'Attack': 105,
#   'Defense': 75,
#   'HP': 75,
#   'Name': 'Octillery',
#   'PokedexNumber': 224,
#   'SpecialAttack': 105,
#   'SpecialDefense': 75,
#   'Speed': 45,
#   'Total': 480,
#   'Type': 'Water'},
#  225: {'Attack': 55,
#   'Defense': 45,
#   'HP': 45,
#   'Name': 'Delibird',
#   'PokedexNumber': 225,
#   'SpecialAttack': 65,
#   'SpecialDefense': 45,
#   'Speed': 75,
#   'Total': 330,
#   'Type': 'IceFlying'},
#  226: {'Attack': 40,
#   'Defense': 70,
#   'HP': 65,
#   'Name': 'Mantine',
#   'PokedexNumber': 226,
#   'SpecialAttack': 80,
#   'SpecialDefense': 140,
#   'Speed': 70,
#   'Total': 465,
#   'Type': 'WaterFlying'},
#  227: {'Attack': 80,
#   'Defense': 140,
#   'HP': 65,
#   'Name': 'Skarmory',
#   'PokedexNumber': 227,
#   'SpecialAttack': 40,
#   'SpecialDefense': 70,
#   'Speed': 70,
#   'Total': 465,
#   'Type': 'SteelFlying'},
#  228: {'Attack': 60,
#   'Defense': 30,
#   'HP': 45,
#   'Name': 'Houndour',
#   'PokedexNumber': 228,
#   'SpecialAttack': 80,
#   'SpecialDefense': 50,
#   'Speed': 65,
#   'Total': 330,
#   'Type': 'DarkFire'},
#  229: {'Attack': 90,
#   'Defense': 90,
#   'HP': 75,
#   'Name': 'HoundoomMega Houndoom',
#   'PokedexNumber': 229,
#   'SpecialAttack': 140,
#   'SpecialDefense': 90,
#   'Speed': 115,
#   'Total': 600,
#   'Type': 'DarkFire'},
#  230: {'Attack': 95,
#   'Defense': 95,
#   'HP': 75,
#   'Name': 'Kingdra',
#   'PokedexNumber': 230,
#   'SpecialAttack': 95,
#   'SpecialDefense': 95,
#   'Speed': 85,
#   'Total': 540,
#   'Type': 'WaterDragon'},
#  231: {'Attack': 60,
#   'Defense': 60,
#   'HP': 90,
#   'Name': 'Phanpy',
#   'PokedexNumber': 231,
#   'SpecialAttack': 40,
#   'SpecialDefense': 40,
#   'Speed': 40,
#   'Total': 330,
#   'Type': 'Ground'},
#  232: {'Attack': 120,
#   'Defense': 120,
#   'HP': 90,
#   'Name': 'Donphan',
#   'PokedexNumber': 232,
#   'SpecialAttack': 60,
#   'SpecialDefense': 60,
#   'Speed': 50,
#   'Total': 500,
#   'Type': 'Ground'},
#  233: {'Attack': 80,
#   'Defense': 90,
#   'HP': 85,
#   'Name': 'Porygon2',
#   'PokedexNumber': 233,
#   'SpecialAttack': 105,
#   'SpecialDefense': 95,
#   'Speed': 60,
#   'Total': 515,
#   'Type': 'Normal'},
#  234: {'Attack': 95,
#   'Defense': 62,
#   'HP': 73,
#   'Name': 'Stantler',
#   'PokedexNumber': 234,
#   'SpecialAttack': 85,
#   'SpecialDefense': 65,
#   'Speed': 85,
#   'Total': 465,
#   'Type': 'Normal'},
#  235: {'Attack': 20,
#   'Defense': 35,
#   'HP': 55,
#   'Name': 'Smeargle',
#   'PokedexNumber': 235,
#   'SpecialAttack': 20,
#   'SpecialDefense': 45,
#   'Speed': 75,
#   'Total': 250,
#   'Type': 'Normal'},
#  236: {'Attack': 35,
#   'Defense': 35,
#   'HP': 35,
#   'Name': 'Tyrogue',
#   'PokedexNumber': 236,
#   'SpecialAttack': 35,
#   'SpecialDefense': 35,
#   'Speed': 35,
#   'Total': 210,
#   'Type': 'Fighting'},
#  237: {'Attack': 95,
#   'Defense': 95,
#   'HP': 50,
#   'Name': 'Hitmontop',
#   'PokedexNumber': 237,
#   'SpecialAttack': 35,
#   'SpecialDefense': 110,
#   'Speed': 70,
#   'Total': 455,
#   'Type': 'Fighting'},
#  238: {'Attack': 30,
#   'Defense': 15,
#   'HP': 45,
#   'Name': 'Smoochum',
#   'PokedexNumber': 238,
#   'SpecialAttack': 85,
#   'SpecialDefense': 65,
#   'Speed': 65,
#   'Total': 305,
#   'Type': 'IcePsychic'},
#  239: {'Attack': 63,
#   'Defense': 37,
#   'HP': 45,
#   'Name': 'Elekid',
#   'PokedexNumber': 239,
#   'SpecialAttack': 65,
#   'SpecialDefense': 55,
#   'Speed': 95,
#   'Total': 360,
#   'Type': 'Electric'},
#  240: {'Attack': 75,
#   'Defense': 37,
#   'HP': 45,
#   'Name': 'Magby',
#   'PokedexNumber': 240,
#   'SpecialAttack': 70,
#   'SpecialDefense': 55,
#   'Speed': 83,
#   'Total': 365,
#   'Type': 'Fire'},
#  241: {'Attack': 80,
#   'Defense': 105,
#   'HP': 95,
#   'Name': 'Miltank',
#   'PokedexNumber': 241,
#   'SpecialAttack': 40,
#   'SpecialDefense': 70,
#   'Speed': 100,
#   'Total': 490,
#   'Type': 'Normal'},
#  242: {'Attack': 10,
#   'Defense': 10,
#   'HP': 255,
#   'Name': 'Blissey',
#   'PokedexNumber': 242,
#   'SpecialAttack': 75,
#   'SpecialDefense': 135,
#   'Speed': 55,
#   'Total': 540,
#   'Type': 'Normal'},
#  243: {'Attack': 85,
#   'Defense': 75,
#   'HP': 90,
#   'Name': 'Raikou',
#   'PokedexNumber': 243,
#   'SpecialAttack': 115,
#   'SpecialDefense': 100,
#   'Speed': 115,
#   'Total': 580,
#   'Type': 'Electric'},
#  244: {'Attack': 115,
#   'Defense': 85,
#   'HP': 115,
#   'Name': 'Entei',
# ...
#   'Defense': 70,
#   'HP': 79,
#   'Name': 'ThundurusTherian Forme',
#   'PokedexNumber': 642,
#   'SpecialAttack': 145,
#   'SpecialDefense': 80,
#   'Speed': 101,
#   'Total': 580,
#   'Type': 'ElectricFlying'},
#  643: {'Attack': 120,
#   'Defense': 100,
#   'HP': 100,
#   'Name': 'Reshiram',
#   'PokedexNumber': 643,
#   'SpecialAttack': 150,
#   'SpecialDefense': 120,
#   'Speed': 90,
#   'Total': 680,
#   'Type': 'DragonFire'},
#  644: {'Attack': 150,
#   'Defense': 120,
#   'HP': 100,
#   'Name': 'Zekrom',
#   'PokedexNumber': 644,
#   'SpecialAttack': 120,
#   'SpecialDefense': 100,
#   'Speed': 90,
#   'Total': 680,
#   'Type': 'DragonElectric'},
#  645: {'Attack': 145,
#   'Defense': 90,
#   'HP': 89,
#   'Name': 'LandorusTherian Forme',
#   'PokedexNumber': 645,
#   'SpecialAttack': 105,
#   'SpecialDefense': 80,
#   'Speed': 91,
#   'Total': 600,
#   'Type': 'GroundFlying'},
#  646: {'Attack': 120,
#   'Defense': 90,
#   'HP': 125,
#   'Name': 'KyuremWhite Kyurem',
#   'PokedexNumber': 646,
#   'SpecialAttack': 170,
#   'SpecialDefense': 100,
#   'Speed': 95,
#   'Total': 700,
#   'Type': 'DragonIce'},
#  647: {'Attack': 72,
#   'Defense': 90,
#   'HP': 91,
#   'Name': 'KeldeoResolute Forme',
#   'PokedexNumber': 647,
#   'SpecialAttack': 129,
#   'SpecialDefense': 90,
#   'Speed': 108,
#   'Total': 580,
#   'Type': 'WaterFighting'},
#  648: {'Attack': 128,
#   'Defense': 90,
#   'HP': 100,
#   'Name': 'MeloettaPirouette Forme',
#   'PokedexNumber': 648,
#   'SpecialAttack': 77,
#   'SpecialDefense': 77,
#   'Speed': 128,
#   'Total': 600,
#   'Type': 'NormalFighting'},
#  649: {'Attack': 120,
#   'Defense': 95,
#   'HP': 71,
#   'Name': 'Genesect',
#   'PokedexNumber': 649,
#   'SpecialAttack': 120,
#   'SpecialDefense': 95,
#   'Speed': 99,
#   'Total': 600,
#   'Type': 'BugSteel'},
#  650: {'Attack': 61,
#   'Defense': 65,
#   'HP': 56,
#   'Name': 'Chespin',
#   'PokedexNumber': 650,
#   'SpecialAttack': 48,
#   'SpecialDefense': 45,
#   'Speed': 38,
#   'Total': 313,
#   'Type': 'Grass'},
#  651: {'Attack': 78,
#   'Defense': 95,
#   'HP': 61,
#   'Name': 'Quilladin',
#   'PokedexNumber': 651,
#   'SpecialAttack': 56,
#   'SpecialDefense': 58,
#   'Speed': 57,
#   'Total': 405,
#   'Type': 'Grass'},
#  652: {'Attack': 107,
#   'Defense': 122,
#   'HP': 88,
#   'Name': 'Chesnaught',
#   'PokedexNumber': 652,
#   'SpecialAttack': 74,
#   'SpecialDefense': 75,
#   'Speed': 64,
#   'Total': 530,
#   'Type': 'GrassFighting'},
#  653: {'Attack': 45,
#   'Defense': 40,
#   'HP': 40,
#   'Name': 'Fennekin',
#   'PokedexNumber': 653,
#   'SpecialAttack': 62,
#   'SpecialDefense': 60,
#   'Speed': 60,
#   'Total': 307,
#   'Type': 'Fire'},
#  654: {'Attack': 59,
#   'Defense': 58,
#   'HP': 59,
#   'Name': 'Braixen',
#   'PokedexNumber': 654,
#   'SpecialAttack': 90,
#   'SpecialDefense': 70,
#   'Speed': 73,
#   'Total': 409,
#   'Type': 'Fire'},
#  655: {'Attack': 69,
#   'Defense': 72,
#   'HP': 75,
#   'Name': 'Delphox',
#   'PokedexNumber': 655,
#   'SpecialAttack': 114,
#   'SpecialDefense': 100,
#   'Speed': 104,
#   'Total': 534,
#   'Type': 'FirePsychic'},
#  656: {'Attack': 56,
#   'Defense': 40,
#   'HP': 41,
#   'Name': 'Froakie',
#   'PokedexNumber': 656,
#   'SpecialAttack': 62,
#   'SpecialDefense': 44,
#   'Speed': 71,
#   'Total': 314,
#   'Type': 'Water'},
#  657: {'Attack': 63,
#   'Defense': 52,
#   'HP': 54,
#   'Name': 'Frogadier',
#   'PokedexNumber': 657,
#   'SpecialAttack': 83,
#   'SpecialDefense': 56,
#   'Speed': 97,
#   'Total': 405,
#   'Type': 'Water'},
#  658: {'Attack': 95,
#   'Defense': 67,
#   'HP': 72,
#   'Name': 'Greninja',
#   'PokedexNumber': 658,
#   'SpecialAttack': 103,
#   'SpecialDefense': 71,
#   'Speed': 122,
#   'Total': 530,
#   'Type': 'WaterDark'},
#  659: {'Attack': 36,
#   'Defense': 38,
#   'HP': 38,
#   'Name': 'Bunnelby',
#   'PokedexNumber': 659,
#   'SpecialAttack': 32,
#   'SpecialDefense': 36,
#   'Speed': 57,
#   'Total': 237,
#   'Type': 'Normal'},
#  660: {'Attack': 56,
#   'Defense': 77,
#   'HP': 85,
#   'Name': 'Diggersby',
#   'PokedexNumber': 660,
#   'SpecialAttack': 50,
#   'SpecialDefense': 77,
#   'Speed': 78,
#   'Total': 423,
#   'Type': 'NormalGround'},
#  661: {'Attack': 50,
#   'Defense': 43,
#   'HP': 45,
#   'Name': 'Fletchling',
#   'PokedexNumber': 661,
#   'SpecialAttack': 40,
#   'SpecialDefense': 38,
#   'Speed': 62,
#   'Total': 278,
#   'Type': 'NormalFlying'},
#  662: {'Attack': 73,
#   'Defense': 55,
#   'HP': 62,
#   'Name': 'Fletchinder',
#   'PokedexNumber': 662,
#   'SpecialAttack': 56,
#   'SpecialDefense': 52,
#   'Speed': 84,
#   'Total': 382,
#   'Type': 'FireFlying'},
#  663: {'Attack': 81,
#   'Defense': 71,
#   'HP': 78,
#   'Name': 'Talonflame',
#   'PokedexNumber': 663,
#   'SpecialAttack': 74,
#   'SpecialDefense': 69,
#   'Speed': 126,
#   'Total': 499,
#   'Type': 'FireFlying'},
#  664: {'Attack': 35,
#   'Defense': 40,
#   'HP': 38,
#   'Name': 'Scatterbug',
#   'PokedexNumber': 664,
#   'SpecialAttack': 27,
#   'SpecialDefense': 25,
#   'Speed': 35,
#   'Total': 200,
#   'Type': 'Bug'},
#  665: {'Attack': 22,
#   'Defense': 60,
#   'HP': 45,
#   'Name': 'Spewpa',
#   'PokedexNumber': 665,
#   'SpecialAttack': 27,
#   'SpecialDefense': 30,
#   'Speed': 29,
#   'Total': 213,
#   'Type': 'Bug'},
#  666: {'Attack': 52,
#   'Defense': 50,
#   'HP': 80,
#   'Name': 'Vivillon',
#   'PokedexNumber': 666,
#   'SpecialAttack': 90,
#   'SpecialDefense': 50,
#   'Speed': 89,
#   'Total': 411,
#   'Type': 'BugFlying'},
#  667: {'Attack': 50,
#   'Defense': 58,
#   'HP': 62,
#   'Name': 'Litleo',
#   'PokedexNumber': 667,
#   'SpecialAttack': 73,
#   'SpecialDefense': 54,
#   'Speed': 72,
#   'Total': 369,
#   'Type': 'FireNormal'},
#  668: {'Attack': 68,
#   'Defense': 72,
#   'HP': 86,
#   'Name': 'Pyroar',
#   'PokedexNumber': 668,
#   'SpecialAttack': 109,
#   'SpecialDefense': 66,
#   'Speed': 106,
#   'Total': 507,
#   'Type': 'FireNormal'},
#  669: {'Attack': 38,
#   'Defense': 39,
#   'HP': 44,
#   'Name': 'Flabebe',
#   'PokedexNumber': 669,
#   'SpecialAttack': 61,
#   'SpecialDefense': 79,
#   'Speed': 42,
#   'Total': 303,
#   'Type': 'Fairy'},
#  670: {'Attack': 45,
#   'Defense': 47,
#   'HP': 54,
#   'Name': 'Floette',
#   'PokedexNumber': 670,
#   'SpecialAttack': 75,
#   'SpecialDefense': 98,
#   'Speed': 52,
#   'Total': 371,
#   'Type': 'Fairy'},
#  671: {'Attack': 65,
#   'Defense': 68,
#   'HP': 78,
#   'Name': 'Florges',
#   'PokedexNumber': 671,
#   'SpecialAttack': 112,
#   'SpecialDefense': 154,
#   'Speed': 75,
#   'Total': 552,
#   'Type': 'Fairy'},
#  672: {'Attack': 65,
#   'Defense': 48,
#   'HP': 66,
#   'Name': 'Skiddo',
#   'PokedexNumber': 672,
#   'SpecialAttack': 62,
#   'SpecialDefense': 57,
#   'Speed': 52,
#   'Total': 350,
#   'Type': 'Grass'},
#  673: {'Attack': 100,
#   'Defense': 62,
#   'HP': 123,
#   'Name': 'Gogoat',
#   'PokedexNumber': 673,
#   'SpecialAttack': 97,
#   'SpecialDefense': 81,
#   'Speed': 68,
#   'Total': 531,
#   'Type': 'Grass'},
#  674: {'Attack': 82,
#   'Defense': 62,
#   'HP': 67,
#   'Name': 'Pancham',
#   'PokedexNumber': 674,
#   'SpecialAttack': 46,
#   'SpecialDefense': 48,
#   'Speed': 43,
#   'Total': 348,
#   'Type': 'Fighting'},
#  675: {'Attack': 124,
#   'Defense': 78,
#   'HP': 95,
#   'Name': 'Pangoro',
#   'PokedexNumber': 675,
#   'SpecialAttack': 69,
#   'SpecialDefense': 71,
#   'Speed': 58,
#   'Total': 495,
#   'Type': 'FightingDark'},
#  676: {'Attack': 80,
#   'Defense': 60,
#   'HP': 75,
#   'Name': 'Furfrou',
#   'PokedexNumber': 676,
#   'SpecialAttack': 65,
#   'SpecialDefense': 90,
#   'Speed': 102,
#   'Total': 472,
#   'Type': 'Normal'},
#  677: {'Attack': 48,
#   'Defense': 54,
#   'HP': 62,
#   'Name': 'Espurr',
#   'PokedexNumber': 677,
#   'SpecialAttack': 63,
#   'SpecialDefense': 60,
#   'Speed': 68,
#   'Total': 355,
#   'Type': 'Psychic'},
#  678: {'Attack': 48,
#   'Defense': 76,
#   'HP': 74,
#   'Name': 'MeowsticFemale',
#   'PokedexNumber': 678,
#   'SpecialAttack': 83,
#   'SpecialDefense': 81,
#   'Speed': 104,
#   'Total': 466,
#   'Type': 'Psychic'},
#  679: {'Attack': 80,
#   'Defense': 100,
#   'HP': 45,
#   'Name': 'Honedge',
#   'PokedexNumber': 679,
#   'SpecialAttack': 35,
#   'SpecialDefense': 37,
#   'Speed': 28,
#   'Total': 325,
#   'Type': 'SteelGhost'},
#  680: {'Attack': 110,
#   'Defense': 150,
#   'HP': 59,
#   'Name': 'Doublade',
#   'PokedexNumber': 680,
#   'SpecialAttack': 45,
#   'SpecialDefense': 49,
#   'Speed': 35,
#   'Total': 448,
#   'Type': 'SteelGhost'},
#  681: {'Attack': 50,
#   'Defense': 150,
#   'HP': 60,
#   'Name': 'AegislashShield Forme',
#   'PokedexNumber': 681,
#   'SpecialAttack': 50,
#   'SpecialDefense': 150,
#   'Speed': 60,
#   'Total': 520,
#   'Type': 'SteelGhost'},
#  682: {'Attack': 52,
#   'Defense': 60,
#   'HP': 78,
#   'Name': 'Spritzee',
#   'PokedexNumber': 682,
#   'SpecialAttack': 63,
#   'SpecialDefense': 65,
#   'Speed': 23,
#   'Total': 341,
#   'Type': 'Fairy'},
#  683: {'Attack': 72,
#   'Defense': 72,
#   'HP': 101,
#   'Name': 'Aromatisse',
#   'PokedexNumber': 683,
#   'SpecialAttack': 99,
#   'SpecialDefense': 89,
#   'Speed': 29,
#   'Total': 462,
#   'Type': 'Fairy'},
#  684: {'Attack': 48,
#   'Defense': 66,
#   'HP': 62,
#   'Name': 'Swirlix',
#   'PokedexNumber': 684,
#   'SpecialAttack': 59,
#   'SpecialDefense': 57,
#   'Speed': 49,
#   'Total': 341,
#   'Type': 'Fairy'},
#  685: {'Attack': 80,
#   'Defense': 86,
#   'HP': 82,
#   'Name': 'Slurpuff',
#   'PokedexNumber': 685,
#   'SpecialAttack': 85,
#   'SpecialDefense': 75,
#   'Speed': 72,
#   'Total': 480,
#   'Type': 'Fairy'},
#  686: {'Attack': 54,
#   'Defense': 53,
#   'HP': 53,
#   'Name': 'Inkay',
#   'PokedexNumber': 686,
#   'SpecialAttack': 37,
#   'SpecialDefense': 46,
#   'Speed': 45,
#   'Total': 288,
#   'Type': 'DarkPsychic'},
#  687: {'Attack': 92,
#   'Defense': 88,
#   'HP': 86,
#   'Name': 'Malamar',
#   'PokedexNumber': 687,
#   'SpecialAttack': 68,
#   'SpecialDefense': 75,
#   'Speed': 73,
#   'Total': 482,
#   'Type': 'DarkPsychic'},
#  688: {'Attack': 52,
#   'Defense': 67,
#   'HP': 42,
#   'Name': 'Binacle',
#   'PokedexNumber': 688,
#   'SpecialAttack': 39,
#   'SpecialDefense': 56,
#   'Speed': 50,
#   'Total': 306,
#   'Type': 'RockWater'},
#  689: {'Attack': 105,
#   'Defense': 115,
#   'HP': 72,
#   'Name': 'Barbaracle',
#   'PokedexNumber': 689,
#   'SpecialAttack': 54,
#   'SpecialDefense': 86,
#   'Speed': 68,
#   'Total': 500,
#   'Type': 'RockWater'},
#  690: {'Attack': 60,
#   'Defense': 60,
#   'HP': 50,
#   'Name': 'Skrelp',
#   'PokedexNumber': 690,
#   'SpecialAttack': 60,
#   'SpecialDefense': 60,
#   'Speed': 30,
#   'Total': 320,
#   'Type': 'PoisonWater'},
#  691: {'Attack': 75,
#   'Defense': 90,
#   'HP': 65,
#   'Name': 'Dragalge',
#   'PokedexNumber': 691,
#   'SpecialAttack': 97,
#   'SpecialDefense': 123,
#   'Speed': 44,
#   'Total': 494,
#   'Type': 'PoisonDragon'},
#  692: {'Attack': 53,
#   'Defense': 62,
#   'HP': 50,
#   'Name': 'Clauncher',
#   'PokedexNumber': 692,
#   'SpecialAttack': 58,
#   'SpecialDefense': 63,
#   'Speed': 44,
#   'Total': 330,
#   'Type': 'Water'},
#  693: {'Attack': 73,
#   'Defense': 88,
#   'HP': 71,
#   'Name': 'Clawitzer',
#   'PokedexNumber': 693,
#   'SpecialAttack': 120,
#   'SpecialDefense': 89,
#   'Speed': 59,
#   'Total': 500,
#   'Type': 'Water'},
#  694: {'Attack': 38,
#   'Defense': 33,
#   'HP': 44,
#   'Name': 'Helioptile',
#   'PokedexNumber': 694,
#   'SpecialAttack': 61,
#   'SpecialDefense': 43,
#   'Speed': 70,
#   'Total': 289,
#   'Type': 'ElectricNormal'},
#  695: {'Attack': 55,
#   'Defense': 52,
#   'HP': 62,
#   'Name': 'Heliolisk',
#   'PokedexNumber': 695,
#   'SpecialAttack': 109,
#   'SpecialDefense': 94,
#   'Speed': 109,
#   'Total': 481,
#   'Type': 'ElectricNormal'},
#  696: {'Attack': 89,
#   'Defense': 77,
#   'HP': 58,
#   'Name': 'Tyrunt',
#   'PokedexNumber': 696,
#   'SpecialAttack': 45,
#   'SpecialDefense': 45,
#   'Speed': 48,
#   'Total': 362,
#   'Type': 'RockDragon'},
#  697: {'Attack': 121,
#   'Defense': 119,
#   'HP': 82,
#   'Name': 'Tyrantrum',
#   'PokedexNumber': 697,
#   'SpecialAttack': 69,
#   'SpecialDefense': 59,
#   'Speed': 71,
#   'Total': 521,
#   'Type': 'RockDragon'},
#  698: {'Attack': 59,
#   'Defense': 50,
#   'HP': 77,
#   'Name': 'Amaura',
#   'PokedexNumber': 698,
#   'SpecialAttack': 67,
#   'SpecialDefense': 63,
#   'Speed': 46,
#   'Total': 362,
#   'Type': 'RockIce'},
#  699: {'Attack': 77,
#   'Defense': 72,
#   'HP': 123,
#   'Name': 'Aurorus',
#   'PokedexNumber': 699,
#   'SpecialAttack': 99,
#   'SpecialDefense': 92,
#   'Speed': 58,
#   'Total': 521,
#   'Type': 'RockIce'},
#  700: {'Attack': 65,
#   'Defense': 65,
#   'HP': 95,
#   'Name': 'Sylveon',
#   'PokedexNumber': 700,
#   'SpecialAttack': 110,
#   'SpecialDefense': 130,
#   'Speed': 60,
#   'Total': 525,
#   'Type': 'Fairy'},
#  701: {'Attack': 92,
#   'Defense': 75,
#   'HP': 78,
#   'Name': 'Hawlucha',
#   'PokedexNumber': 701,
#   'SpecialAttack': 74,
#   'SpecialDefense': 63,
#   'Speed': 118,
#   'Total': 500,
#   'Type': 'FightingFlying'},
#  702: {'Attack': 58,
#   'Defense': 57,
#   'HP': 67,
#   'Name': 'Dedenne',
#   'PokedexNumber': 702,
#   'SpecialAttack': 81,
#   'SpecialDefense': 67,
#   'Speed': 101,
#   'Total': 431,
#   'Type': 'ElectricFairy'},
#  703: {'Attack': 50,
#   'Defense': 150,
#   'HP': 50,
#   'Name': 'Carbink',
#   'PokedexNumber': 703,
#   'SpecialAttack': 50,
#   'SpecialDefense': 150,
#   'Speed': 50,
#   'Total': 500,
#   'Type': 'RockFairy'},
#  704: {'Attack': 50,
#   'Defense': 35,
#   'HP': 45,
#   'Name': 'Goomy',
#   'PokedexNumber': 704,
#   'SpecialAttack': 55,
#   'SpecialDefense': 75,
#   'Speed': 40,
#   'Total': 300,
#   'Type': 'Dragon'},
#  705: {'Attack': 75,
#   'Defense': 53,
#   'HP': 68,
#   'Name': 'Sliggoo',
#   'PokedexNumber': 705,
#   'SpecialAttack': 83,
#   'SpecialDefense': 113,
#   'Speed': 60,
#   'Total': 452,
#   'Type': 'Dragon'},
#  706: {'Attack': 100,
#   'Defense': 70,
#   'HP': 90,
#   'Name': 'Goodra',
#   'PokedexNumber': 706,
#   'SpecialAttack': 110,
#   'SpecialDefense': 150,
#   'Speed': 80,
#   'Total': 600,
#   'Type': 'Dragon'},
#  707: {'Attack': 80,
#   'Defense': 91,
#   'HP': 57,
#   'Name': 'Klefki',
#   'PokedexNumber': 707,
#   'SpecialAttack': 80,
#   'SpecialDefense': 87,
#   'Speed': 75,
#   'Total': 470,
#   'Type': 'SteelFairy'},
#  708: {'Attack': 70,
#   'Defense': 48,
#   'HP': 43,
#   'Name': 'Phantump',
#   'PokedexNumber': 708,
#   'SpecialAttack': 50,
#   'SpecialDefense': 60,
#   'Speed': 38,
#   'Total': 309,
#   'Type': 'GhostGrass'},
#  709: {'Attack': 110,
#   'Defense': 76,
#   'HP': 85,
#   'Name': 'Trevenant',
#   'PokedexNumber': 709,
#   'SpecialAttack': 65,
#   'SpecialDefense': 82,
#   'Speed': 56,
#   'Total': 474,
#   'Type': 'GhostGrass'},
#  710: {'Attack': 66,
#   'Defense': 70,
#   'HP': 59,
#   'Name': 'PumpkabooSuper Size',
#   'PokedexNumber': 710,
#   'SpecialAttack': 44,
#   'SpecialDefense': 55,
#   'Speed': 41,
#   'Total': 335,
#   'Type': 'GhostGrass'},
#  711: {'Attack': 100,
#   'Defense': 122,
#   'HP': 85,
#   'Name': 'GourgeistSuper Size',
#   'PokedexNumber': 711,
#   'SpecialAttack': 58,
#   'SpecialDefense': 75,
#   'Speed': 54,
#   'Total': 494,
#   'Type': 'GhostGrass'},
#  712: {'Attack': 69,
#   'Defense': 85,
#   'HP': 55,
#   'Name': 'Bergmite',
#   'PokedexNumber': 712,
#   'SpecialAttack': 32,
#   'SpecialDefense': 35,
#   'Speed': 28,
#   'Total': 304,
#   'Type': 'Ice'},
#  713: {'Attack': 117,
#   'Defense': 184,
#   'HP': 95,
#   'Name': 'Avalugg',
#   'PokedexNumber': 713,
#   'SpecialAttack': 44,
#   'SpecialDefense': 46,
#   'Speed': 28,
#   'Total': 514,
#   'Type': 'Ice'},
#  714: {'Attack': 30,
#   'Defense': 35,
#   'HP': 40,
#   'Name': 'Noibat',
#   'PokedexNumber': 714,
#   'SpecialAttack': 45,
#   'SpecialDefense': 40,
#   'Speed': 55,
#   'Total': 245,
#   'Type': 'FlyingDragon'},
#  715: {'Attack': 70,
#   'Defense': 80,
#   'HP': 85,
#   'Name': 'Noivern',
#   'PokedexNumber': 715,
#   'SpecialAttack': 97,
#   'SpecialDefense': 80,
#   'Speed': 123,
#   'Total': 535,
#   'Type': 'FlyingDragon'},
#  716: {'Attack': 131,
#   'Defense': 95,
#   'HP': 126,
#   'Name': 'Xerneas',
#   'PokedexNumber': 716,
#   'SpecialAttack': 131,
#   'SpecialDefense': 98,
#   'Speed': 99,
#   'Total': 680,
#   'Type': 'Fairy'},
#  717: {'Attack': 131,
#   'Defense': 95,
#   'HP': 126,
#   'Name': 'Yveltal',
#   'PokedexNumber': 717,
#   'SpecialAttack': 131,
#   'SpecialDefense': 98,
#   'Speed': 99,
#   'Total': 680,
#   'Type': 'DarkFlying'},
#  718: {'Attack': 100,
#   'Defense': 121,
#   'HP': 108,
#   'Name': 'Zygarde Forme',
#   'PokedexNumber': 718,
#   'SpecialAttack': 81,
#   'SpecialDefense': 95,
#   'Speed': 95,
#   'Total': 600,
#   'Type': 'DragonGround'},
#  719: {'Attack': 160,
#   'Defense': 110,
#   'HP': 50,
#   'Name': 'DiancieMega Diancie',
#   'PokedexNumber': 719,
#   'SpecialAttack': 160,
#   'SpecialDefense': 110,
#   'Speed': 110,
#   'Total': 700,
#   'Type': 'RockFairy'},
#  720: {'Attack': 160,
#   'Defense': 60,
#   'HP': 80,
#   'Name': 'HoopaHoopa Unbound',
#   'PokedexNumber': 720,
#   'SpecialAttack': 170,
#   'SpecialDefense': 130,
#   'Speed': 80,
#   'Total': 680,
#   'Type': 'PsychicDark'},
#  721: {'Attack': 110,
#   'Defense': 120,
#   'HP': 80,
#   'Name': 'Volcanion',
#   'PokedexNumber': 721,
#   'SpecialAttack': 130,
#   'SpecialDefense': 90,
#   'Speed': 70,
#   'Total': 600,
#   'Type': 'FireWater'}}

# %%
new_pokedex[100]
# Out:
# {'Attack': 30,
#  'Defense': 50,
#  'HP': 40,
#  'Name': 'Voltorb',
#  'PokedexNumber': 100,
#  'SpecialAttack': 55,
#  'SpecialDefense': 55,
#  'Speed': 100,
#  'Total': 330,
#  'Type': 'Electric'}

# %%
pokedex_file.loc[100]
# Out:
# PokedexNumber          100
# Name               Voltorb
# Type              Electric
# Total                  330
# HP                      40
# Attack                  30
# Defense                 50
# SpecialAttack           55
# SpecialDefense          55
# Speed                  100
# Name: 100, dtype: object

# %% [markdown]
# <img src="http://i.imgur.com/GCAf1UX.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Write a function to generate a "filtered" pokedex
# ---
# Your function should:
# 1. Take the parsed pokedex information you created above as an argument.
# 1. Take a dictionary as a parameter with keys matching the features of the Pokedex, filtering by exact match for string type values, and/or filter continuous variables specified value that is greater than or equal to the dictionary key parameter.
# 1. Return multiple elements from the Pokedex
#
# Example:
#
# ```python
#
# # Only filter based on parameters passed
# filter_options = {
#     'Attack':   25,
#     'Defense':  30,
#     'Type':     'Electric'
# }
#
# # Return records with attack >= 24, defense >= 30, and type == "Electric"
# # Also anticipate that other paramters can also be passed such as "SpecialAttack", "Speed", etc.
# filtered_pokedex(pokedex_data, filter=filter_options)
#
# # Example output:
# # [{'Attack': 30.0,
# #  'Defense': 50.0,
# #  'HP': 40.0,
# #  'Name': 'Voltorb',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  {'Attack': 30.0,
# #  'Defense': 33.0,
# #  'HP': 32.0,
# #  'Name': 'Pikachu',
# #  'SpecialAttack': 55.0,
# #  'SpecialDefense': 55.0,
# #  'Speed': 100.0,
# #  'Total': 330.0,
# #  'Type': 'Electric'},
# #  ... etc
# #  ]
#
# ```

# %%
def pokedex_filter(pokedex, filter):
    answer = []
    for pokemon in pokedex.values():
        display = True
        for filter_key in filter:
            if type(filter[filter_key]) == type(''):
                if pokemon[filter_key] != filter[filter_key]:
                    display = False
                    break
            else:
                if pokemon[filter_key] < filter[filter_key]:
                    display = False
                    break                   
        if display:
            answer.append(pokemon)
    return answer
                
filter_options = {
    'Attack':   25,
    'Defense':  30,
    'Type':     'Electric'
}
pokedex_filter(new_pokedex, filter_options)
# Out:
# [{'Attack': 55,
#   'Defense': 40,
#   'HP': 35,
#   'Name': 'Pikachu',
#   'PokedexNumber': 25,
#   'SpecialAttack': 50,
#   'SpecialDefense': 50,
#   'Speed': 90,
#   'Total': 320,
#   'Type': 'Electric'},
#  {'Attack': 90,
#   'Defense': 55,
#   'HP': 60,
#   'Name': 'Raichu',
#   'PokedexNumber': 26,
#   'SpecialAttack': 90,
#   'SpecialDefense': 80,
#   'Speed': 110,
#   'Total': 485,
#   'Type': 'Electric'},
#  {'Attack': 30,
#   'Defense': 50,
#   'HP': 40,
#   'Name': 'Voltorb',
#   'PokedexNumber': 100,
#   'SpecialAttack': 55,
#   'SpecialDefense': 55,
#   'Speed': 100,
#   'Total': 330,
#   'Type': 'Electric'},
#  {'Attack': 50,
#   'Defense': 70,
#   'HP': 60,
#   'Name': 'Electrode',
#   'PokedexNumber': 101,
#   'SpecialAttack': 80,
#   'SpecialDefense': 80,
#   'Speed': 140,
#   'Total': 480,
#   'Type': 'Electric'},
#  {'Attack': 83,
#   'Defense': 57,
#   'HP': 65,
#   'Name': 'Electabuzz',
#   'PokedexNumber': 125,
#   'SpecialAttack': 95,
#   'SpecialDefense': 85,
#   'Speed': 105,
#   'Total': 490,
#   'Type': 'Electric'},
#  {'Attack': 65,
#   'Defense': 60,
#   'HP': 65,
#   'Name': 'Jolteon',
#   'PokedexNumber': 135,
#   'SpecialAttack': 110,
#   'SpecialDefense': 95,
#   'Speed': 130,
#   'Total': 525,
#   'Type': 'Electric'},
#  {'Attack': 40,
#   'Defense': 40,
#   'HP': 55,
#   'Name': 'Mareep',
#   'PokedexNumber': 179,
#   'SpecialAttack': 65,
#   'SpecialDefense': 45,
#   'Speed': 35,
#   'Total': 280,
#   'Type': 'Electric'},
#  {'Attack': 55,
#   'Defense': 55,
#   'HP': 70,
#   'Name': 'Flaaffy',
#   'PokedexNumber': 180,
#   'SpecialAttack': 80,
#   'SpecialDefense': 60,
#   'Speed': 45,
#   'Total': 365,
#   'Type': 'Electric'},
#  {'Attack': 63,
#   'Defense': 37,
#   'HP': 45,
#   'Name': 'Elekid',
#   'PokedexNumber': 239,
#   'SpecialAttack': 65,
#   'SpecialDefense': 55,
#   'Speed': 95,
#   'Total': 360,
#   'Type': 'Electric'},
#  {'Attack': 85,
#   'Defense': 75,
#   'HP': 90,
#   'Name': 'Raikou',
#   'PokedexNumber': 243,
#   'SpecialAttack': 115,
#   'SpecialDefense': 100,
#   'Speed': 115,
#   'Total': 580,
#   'Type': 'Electric'},
#  {'Attack': 45,
#   'Defense': 40,
#   'HP': 40,
#   'Name': 'Electrike',
#   'PokedexNumber': 309,
#   'SpecialAttack': 65,
#   'SpecialDefense': 40,
#   'Speed': 65,
#   'Total': 295,
#   'Type': 'Electric'},
#  {'Attack': 75,
#   'Defense': 80,
#   'HP': 70,
#   'Name': 'ManectricMega Manectric',
#   'PokedexNumber': 310,
#   'SpecialAttack': 135,
#   'SpecialDefense': 80,
#   'Speed': 135,
#   'Total': 575,
#   'Type': 'Electric'},
#  {'Attack': 50,
#   'Defense': 40,
#   'HP': 60,
#   'Name': 'Plusle',
#   'PokedexNumber': 311,
#   'SpecialAttack': 85,
#   'SpecialDefense': 75,
#   'Speed': 95,
#   'Total': 405,
#   'Type': 'Electric'},
#  {'Attack': 40,
#   'Defense': 50,
#   'HP': 60,
#   'Name': 'Minun',
#   'PokedexNumber': 312,
#   'SpecialAttack': 75,
#   'SpecialDefense': 85,
#   'Speed': 95,
#   'Total': 405,
#   'Type': 'Electric'},
#  {'Attack': 65,
#   'Defense': 34,
#   'HP': 45,
#   'Name': 'Shinx',
#   'PokedexNumber': 403,
#   'SpecialAttack': 40,
#   'SpecialDefense': 34,
#   'Speed': 45,
#   'Total': 263,
#   'Type': 'Electric'},
#  {'Attack': 85,
#   'Defense': 49,
#   'HP': 60,
#   'Name': 'Luxio',
#   'PokedexNumber': 404,
#   'SpecialAttack': 60,
#   'SpecialDefense': 49,
#   'Speed': 60,
#   'Total': 363,
#   'Type': 'Electric'},
#  {'Attack': 120,
#   'Defense': 79,
#   'HP': 80,
#   'Name': 'Luxray',
#   'PokedexNumber': 405,
#   'SpecialAttack': 95,
#   'SpecialDefense': 79,
#   'Speed': 70,
#   'Total': 523,
#   'Type': 'Electric'},
#  {'Attack': 45,
#   'Defense': 70,
#   'HP': 60,
#   'Name': 'Pachirisu',
#   'PokedexNumber': 417,
#   'SpecialAttack': 45,
#   'SpecialDefense': 90,
#   'Speed': 95,
#   'Total': 405,
#   'Type': 'Electric'},
#  {'Attack': 123,
#   'Defense': 67,
#   'HP': 75,
#   'Name': 'Electivire',
#   'PokedexNumber': 466,
#   'SpecialAttack': 95,
#   'SpecialDefense': 85,
#   'Speed': 95,
#   'Total': 540,
#   'Type': 'Electric'},
#  {'Attack': 60,
#   'Defense': 32,
#   'HP': 45,
#   'Name': 'Blitzle',
#   'PokedexNumber': 522,
#   'SpecialAttack': 50,
#   'SpecialDefense': 32,
#   'Speed': 76,
#   'Total': 295,
#   'Type': 'Electric'},
#  {'Attack': 100,
#   'Defense': 63,
#   'HP': 75,
#   'Name': 'Zebstrika',
#   'PokedexNumber': 523,
#   'SpecialAttack': 80,
#   'SpecialDefense': 63,
#   'Speed': 116,
#   'Total': 497,
#   'Type': 'Electric'},
#  {'Attack': 55,
#   'Defense': 40,
#   'HP': 35,
#   'Name': 'Tynamo',
#   'PokedexNumber': 602,
#   'SpecialAttack': 45,
#   'SpecialDefense': 40,
#   'Speed': 60,
#   'Total': 275,
#   'Type': 'Electric'},
#  {'Attack': 85,
#   'Defense': 70,
#   'HP': 65,
#   'Name': 'Eelektrik',
#   'PokedexNumber': 603,
#   'SpecialAttack': 75,
#   'SpecialDefense': 70,
#   'Speed': 40,
#   'Total': 405,
#   'Type': 'Electric'},
#  {'Attack': 115,
#   'Defense': 80,
#   'HP': 85,
#   'Name': 'Eelektross',
#   'PokedexNumber': 604,
#   'SpecialAttack': 105,
#   'SpecialDefense': 80,
#   'Speed': 50,
#   'Total': 515,
#   'Type': 'Electric'}]

# %%
pokedex_file[(pokedex_file.Attack > 25) & (pokedex_file.Defense > 30) & (pokedex_file.Type == 'Electric')]
# Out:
#             PokedexNumber                     Name      Type  Total  HP  \
# MyNewIndex
# 25                     25                  Pikachu  Electric    320  35
# 26                     26                   Raichu  Electric    485  60
# 100                   100                  Voltorb  Electric    330  40
# 101                   101                Electrode  Electric    480  60
# 125                   125               Electabuzz  Electric    490  65
# 135                   135                  Jolteon  Electric    525  65
# 179                   179                   Mareep  Electric    280  55
# 180                   180                  Flaaffy  Electric    365  70
# 181                   181                 Ampharos  Electric    510  90
# 239                   239                   Elekid  Electric    360  45
# 243                   243                   Raikou  Electric    580  90
# 309                   309                Electrike  Electric    295  40
# 310                   310                Manectric  Electric    475  70
# 310                   310  ManectricMega Manectric  Electric    575  70
# 311                   311                   Plusle  Electric    405  60
# 312                   312                    Minun  Electric    405  60
# 403                   403                    Shinx  Electric    263  45
# 404                   404                    Luxio  Electric    363  60
# 405                   405                   Luxray  Electric    523  80
# 417                   417                Pachirisu  Electric    405  60
# 466                   466               Electivire  Electric    540  75
# 522                   522                  Blitzle  Electric    295  45
# 523                   523                Zebstrika  Electric    497  75
# 602                   602                   Tynamo  Electric    275  35
# 603                   603                Eelektrik  Electric    405  65
# 604                   604               Eelektross  Electric    515  85
#
#             Attack  Defense  SpecialAttack  SpecialDefense  Speed
# MyNewIndex
# 25              55       40             50              50     90
# 26              90       55             90              80    110
# 100             30       50             55              55    100
# 101             50       70             80              80    140
# 125             83       57             95              85    105
# 135             65       60            110              95    130
# 179             40       40             65              45     35
# 180             55       55             80              60     45
# 181             75       85            115              90     55
# 239             63       37             65              55     95
# 243             85       75            115             100    115
# 309             45       40             65              40     65
# 310             75       60            105              60    105
# 310             75       80            135              80    135
# 311             50       40             85              75     95
# 312             40       50             75              85     95
# 403             65       34             40              34     45
# 404             85       49             60              49     60
# 405            120       79             95              79     70
# 417             45       70             45              90     95
# 466            123       67             95              85     95
# 522             60       32             50              32     76
# 523            100       63             80              63    116
# 602             55       40             45              40     60
# 603             85       70             75              70     40
# 604            115       80            105              80     50

# %% [markdown]
# ## 9. Descriptive statistics on the prototype pokedex
#
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.1
#
# What is the population mean and standard deviation of the "Total" attribute for all characters in the Pokedex?

# %%
unduplicated_pokedex = pokedex_file[pokedex_file.PokedexNumber.duplicated() == False]
unduplicated_pokedex
# Out:
#             PokedexNumber                   Name            Type  Total   HP  \
# MyNewIndex
# 1                       1              Bulbasaur     GrassPoison    318   45
# 2                       2                Ivysaur     GrassPoison    405   60
# 3                       3               Venusaur     GrassPoison    525   80
# 4                       4             Charmander            Fire    309   39
# 5                       5             Charmeleon            Fire    405   58
# 6                       6              Charizard      FireFlying    534   78
# 7                       7               Squirtle           Water    314   44
# 8                       8              Wartortle           Water    405   59
# 9                       9              Blastoise           Water    530   79
# 10                     10               Caterpie             Bug    195   45
# 11                     11                Metapod             Bug    205   50
# 12                     12             Butterfree       BugFlying    395   60
# 13                     13                 Weedle       BugPoison    195   40
# 14                     14                 Kakuna       BugPoison    205   45
# 15                     15               Beedrill       BugPoison    395   65
# 16                     16                 Pidgey    NormalFlying    251   40
# 17                     17              Pidgeotto    NormalFlying    349   63
# 18                     18                Pidgeot    NormalFlying    479   83
# 19                     19                Rattata          Normal    253   30
# 20                     20               Raticate          Normal    413   55
# 21                     21                Spearow    NormalFlying    262   40
# 22                     22                 Fearow    NormalFlying    442   65
# 23                     23                  Ekans          Poison    288   35
# 24                     24                  Arbok          Poison    438   60
# 25                     25                Pikachu        Electric    320   35
# 26                     26                 Raichu        Electric    485   60
# 27                     27              Sandshrew          Ground    300   50
# 28                     28              Sandslash          Ground    450   75
# 29                     29               NidoranF          Poison    275   55
# 30                     30               Nidorina          Poison    365   70
# ...                   ...                    ...             ...    ...  ...
# 692                   692              Clauncher           Water    330   50
# 693                   693              Clawitzer           Water    500   71
# 694                   694             Helioptile  ElectricNormal    289   44
# 695                   695              Heliolisk  ElectricNormal    481   62
# 696                   696                 Tyrunt      RockDragon    362   58
# 697                   697              Tyrantrum      RockDragon    521   82
# 698                   698                 Amaura         RockIce    362   77
# 699                   699                Aurorus         RockIce    521  123
# 700                   700                Sylveon           Fairy    525   95
# 701                   701               Hawlucha  FightingFlying    500   78
# 702                   702                Dedenne   ElectricFairy    431   67
# 703                   703                Carbink       RockFairy    500   50
# 704                   704                  Goomy          Dragon    300   45
# 705                   705                Sliggoo          Dragon    452   68
# 706                   706                 Goodra          Dragon    600   90
# 707                   707                 Klefki      SteelFairy    470   57
# 708                   708               Phantump      GhostGrass    309   43
# 709                   709              Trevenant      GhostGrass    474   85
# 710                   710  PumpkabooAverage Size      GhostGrass    335   49
# 711                   711  GourgeistAverage Size      GhostGrass    494   65
# 712                   712               Bergmite             Ice    304   55
# 713                   713                Avalugg             Ice    514   95
# 714                   714                 Noibat    FlyingDragon    245   40
# 715                   715                Noivern    FlyingDragon    535   85
# 716                   716                Xerneas           Fairy    680  126
# 717                   717                Yveltal      DarkFlying    680  126
# 718                   718          Zygarde Forme    DragonGround    600  108
# 719                   719                Diancie       RockFairy    600   50
# 720                   720    HoopaHoopa Confined    PsychicGhost    600   80
# 721                   721              Volcanion       FireWater    600   80
#
#             Attack  Defense  SpecialAttack  SpecialDefense  Speed
# MyNewIndex
# 1               49       49             65              65     45
# 2               62       63             80              80     60
# 3               82       83            100             100     80
# 4               52       43             60              50     65
# 5               64       58             80              65     80
# 6               84       78            109              85    100
# 7               48       65             50              64     43
# 8               63       80             65              80     58
# 9               83      100             85             105     78
# 10              30       35             20              20     45
# 11              20       55             25              25     30
# 12              45       50             90              80     70
# 13              35       30             20              20     50
# 14              25       50             25              25     35
# 15              90       40             45              80     75
# 16              45       40             35              35     56
# 17              60       55             50              50     71
# 18              80       75             70              70    101
# 19              56       35             25              35     72
# 20              81       60             50              70     97
# 21              60       30             31              31     70
# 22              90       65             61              61    100
# 23              60       44             40              54     55
# 24              85       69             65              79     80
# 25              55       40             50              50     90
# 26              90       55             90              80    110
# 27              75       85             20              30     40
# 28             100      110             45              55     65
# 29              47       52             40              40     41
# 30              62       67             55              55     56
# ...            ...      ...            ...             ...    ...
# 692             53       62             58              63     44
# 693             73       88            120              89     59
# 694             38       33             61              43     70
# 695             55       52            109              94    109
# 696             89       77             45              45     48
# 697            121      119             69              59     71
# 698             59       50             67              63     46
# 699             77       72             99              92     58
# 700             65       65            110             130     60
# 701             92       75             74              63    118
# 702             58       57             81              67    101
# 703             50      150             50             150     50
# 704             50       35             55              75     40
# 705             75       53             83             113     60
# 706            100       70            110             150     80
# 707             80       91             80              87     75
# 708             70       48             50              60     38
# 709            110       76             65              82     56
# 710             66       70             44              55     51
# 711             90      122             58              75     84
# 712             69       85             32              35     28
# 713            117      184             44              46     28
# 714             30       35             45              40     55
# 715             70       80             97              80    123
# 716            131       95            131              98     99
# 717            131       95            131              98     99
# 718            100      121             81              95     95
# 719            100      150            100             150     50
# 720            110       60            150             130     70
# 721            110      120            130              90     70
#
# [721 rows x 10 columns]

# %%
unduplicated_pokedex.Total.mean(), unduplicated_pokedex.Total.std()
# Out:
# (417.94590846047157, 109.66367074447545)

# %% [markdown]
# <img src="http://imgur.com/l5NasQj.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
# ### 9.2
#
# The game is no fun if the characters are wildly unbalanced! Are any characters "overpowered", which we'll define as having a "Total" more than three standard deviations from the population mean?

# %%
threshold = unduplicated_pokedex.Total.mean() + 3 * unduplicated_pokedex.Total.std()
pokedex_file[pokedex_file.Total > threshold]
# Out:
#             PokedexNumber                   Name             Type  Total   HP  \
# MyNewIndex
# 150                   150    MewtwoMega Mewtwo X  PsychicFighting    800  126
# 150                   150    MewtwoMega Mewtwo Y          Psychic    780  106
# 382                   382    KyogrePrimal Kyogre            Water    770  100
# 383                   383  GroudonPrimal Groudon       GroundFire    770  100
# 384                   384  RayquazaMega Rayquaza     DragonFlying    780  105
#
#             Attack  Defense  SpecialAttack  SpecialDefense  Speed
# MyNewIndex
# 150            190      100            154             100    130
# 150            150       70            194             120    140
# 382            150       90            180             160     90
# 383            180      160            150              90     90
# 384            180      100            180             100    115

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ## 10. Calibrate the frequency of Pokemon
#
# The design team wants you to make the powerful Pokemon rare, and the weaklings more common. How would you set the probability $p_i$ of finding Pokemon *i* each time a player visits a gym?
#
# Write a function that takes in a Pokedex number and returns a value $p_i$ for that character.
#
# Hint: there are many ways you could do this. What do _you_ think makes sense? Start with simplifying assumptions: for example, you could assume that the probabilities of encountering any two Pokemon on one visit to a gym are independent of each other.

# %%
pokedex_file['InverseTotal'] = 1.0 / pokedex_file.Total
inverse_sum = pokedex_file.InverseTotal.sum()
pokedex_file['probability'] =(pokedex_file.InverseTotal / inverse_sum)
pokedex_file
# Out:
#             PokedexNumber                       Name            Type  Total  \
# MyNewIndex
# 1                       1                  Bulbasaur     GrassPoison    318
# 2                       2                    Ivysaur     GrassPoison    405
# 3                       3                   Venusaur     GrassPoison    525
# 3                       3      VenusaurMega Venusaur     GrassPoison    625
# 4                       4                 Charmander            Fire    309
# 5                       5                 Charmeleon            Fire    405
# 6                       6                  Charizard      FireFlying    534
# 6                       6  CharizardMega Charizard X      FireDragon    634
# 6                       6  CharizardMega Charizard Y      FireFlying    634
# 7                       7                   Squirtle           Water    314
# 8                       8                  Wartortle           Water    405
# 9                       9                  Blastoise           Water    530
# 9                       9    BlastoiseMega Blastoise           Water    630
# 10                     10                   Caterpie             Bug    195
# 11                     11                    Metapod             Bug    205
# 12                     12                 Butterfree       BugFlying    395
# 13                     13                     Weedle       BugPoison    195
# 14                     14                     Kakuna       BugPoison    205
# 15                     15                   Beedrill       BugPoison    395
# 15                     15      BeedrillMega Beedrill       BugPoison    495
# 16                     16                     Pidgey    NormalFlying    251
# 17                     17                  Pidgeotto    NormalFlying    349
# 18                     18                    Pidgeot    NormalFlying    479
# 18                     18        PidgeotMega Pidgeot    NormalFlying    579
# 19                     19                    Rattata          Normal    253
# 20                     20                   Raticate          Normal    413
# 21                     21                    Spearow    NormalFlying    262
# 22                     22                     Fearow    NormalFlying    442
# 23                     23                      Ekans          Poison    288
# 24                     24                      Arbok          Poison    438
# ...                   ...                        ...             ...    ...
# 700                   700                    Sylveon           Fairy    525
# 701                   701                   Hawlucha  FightingFlying    500
# 702                   702                    Dedenne   ElectricFairy    431
# 703                   703                    Carbink       RockFairy    500
# 704                   704                      Goomy          Dragon    300
# 705                   705                    Sliggoo          Dragon    452
# 706                   706                     Goodra          Dragon    600
# 707                   707                     Klefki      SteelFairy    470
# 708                   708                   Phantump      GhostGrass    309
# 709                   709                  Trevenant      GhostGrass    474
# 710                   710      PumpkabooAverage Size      GhostGrass    335
# 710                   710        PumpkabooSmall Size      GhostGrass    335
# 710                   710        PumpkabooLarge Size      GhostGrass    335
# 710                   710        PumpkabooSuper Size      GhostGrass    335
# 711                   711      GourgeistAverage Size      GhostGrass    494
# 711                   711        GourgeistSmall Size      GhostGrass    494
# 711                   711        GourgeistLarge Size      GhostGrass    494
# 711                   711        GourgeistSuper Size      GhostGrass    494
# 712                   712                   Bergmite             Ice    304
# 713                   713                    Avalugg             Ice    514
# 714                   714                     Noibat    FlyingDragon    245
# 715                   715                    Noivern    FlyingDragon    535
# 716                   716                    Xerneas           Fairy    680
# 717                   717                    Yveltal      DarkFlying    680
# 718                   718              Zygarde Forme    DragonGround    600
# 719                   719                    Diancie       RockFairy    600
# 719                   719        DiancieMega Diancie       RockFairy    700
# 720                   720        HoopaHoopa Confined    PsychicGhost    600
# 720                   720         HoopaHoopa Unbound     PsychicDark    680
# 721                   721                  Volcanion       FireWater    600
#
#              HP  Attack  Defense  SpecialAttack  SpecialDefense  Speed  \
# MyNewIndex
# 1            45      49       49             65              65     45
# 2            60      62       63             80              80     60
# 3            80      82       83            100             100     80
# 3            80     100      123            122             120     80
# 4            39      52       43             60              50     65
# 5            58      64       58             80              65     80
# 6            78      84       78            109              85    100
# 6            78     130      111            130              85    100
# 6            78     104       78            159             115    100
# 7            44      48       65             50              64     43
# 8            59      63       80             65              80     58
# 9            79      83      100             85             105     78
# 9            79     103      120            135             115     78
# 10           45      30       35             20              20     45
# 11           50      20       55             25              25     30
# 12           60      45       50             90              80     70
# 13           40      35       30             20              20     50
# 14           45      25       50             25              25     35
# 15           65      90       40             45              80     75
# 15           65     150       40             15              80    145
# 16           40      45       40             35              35     56
# 17           63      60       55             50              50     71
# 18           83      80       75             70              70    101
# 18           83      80       80            135              80    121
# 19           30      56       35             25              35     72
# 20           55      81       60             50              70     97
# 21           40      60       30             31              31     70
# 22           65      90       65             61              61    100
# 23           35      60       44             40              54     55
# 24           60      85       69             65              79     80
# ...         ...     ...      ...            ...             ...    ...
# 700          95      65       65            110             130     60
# 701          78      92       75             74              63    118
# 702          67      58       57             81              67    101
# 703          50      50      150             50             150     50
# 704          45      50       35             55              75     40
# 705          68      75       53             83             113     60
# 706          90     100       70            110             150     80
# 707          57      80       91             80              87     75
# 708          43      70       48             50              60     38
# 709          85     110       76             65              82     56
# 710          49      66       70             44              55     51
# 710          44      66       70             44              55     56
# 710          54      66       70             44              55     46
# 710          59      66       70             44              55     41
# 711          65      90      122             58              75     84
# 711          55      85      122             58              75     99
# 711          75      95      122             58              75     69
# 711          85     100      122             58              75     54
# 712          55      69       85             32              35     28
# 713          95     117      184             44              46     28
# 714          40      30       35             45              40     55
# 715          85      70       80             97              80    123
# 716         126     131       95            131              98     99
# 717         126     131       95            131              98     99
# 718         108     100      121             81              95     95
# 719          50     100      150            100             150     50
# 719          50     160      110            160             110    110
# 720          80     110       60            150             130     70
# 720          80     160       60            170             130     80
# 721          80     110      120            130              90     70
#
#             probability  InverseSum  InverseTotal
# MyNewIndex
# 1              0.001571    0.003145      0.003145
# 2              0.001234    0.002469      0.002469
# 3              0.000952    0.001905      0.001905
# 3              0.000799    0.001600      0.001600
# 4              0.001617    0.003236      0.003236
# 5              0.001234    0.002469      0.002469
# 6              0.000936    0.001873      0.001873
# 6              0.000788    0.001577      0.001577
# 6              0.000788    0.001577      0.001577
# 7              0.001591    0.003185      0.003185
# 8              0.001234    0.002469      0.002469
# 9              0.000943    0.001887      0.001887
# 9              0.000793    0.001587      0.001587
# 10             0.002562    0.005128      0.005128
# 11             0.002437    0.004878      0.004878
# 12             0.001265    0.002532      0.002532
# 13             0.002562    0.005128      0.005128
# 14             0.002437    0.004878      0.004878
# 15             0.001265    0.002532      0.002532
# 15             0.001009    0.002020      0.002020
# 16             0.001991    0.003984      0.003984
# 17             0.001432    0.002865      0.002865
# 18             0.001043    0.002088      0.002088
# 18             0.000863    0.001727      0.001727
# 19             0.001975    0.003953      0.003953
# 20             0.001210    0.002421      0.002421
# 21             0.001907    0.003817      0.003817
# 22             0.001130    0.002262      0.002262
# 23             0.001735    0.003472      0.003472
# 24             0.001141    0.002283      0.002283
# ...                 ...         ...           ...
# 700            0.000952    0.001905      0.001905
# 701            0.000999    0.002000      0.002000
# 702            0.001159    0.002320      0.002320
# 703            0.000999    0.002000      0.002000
# 704            0.001665    0.003333      0.003333
# 705            0.001105    0.002212      0.002212
# 706            0.000833    0.001667      0.001667
# 707            0.001063    0.002128      0.002128
# 708            0.001617    0.003236      0.003236
# 709            0.001054    0.002110      0.002110
# 710            0.001491    0.002985      0.002985
# 710            0.001491    0.002985      0.002985
# 710            0.001491    0.002985      0.002985
# 710            0.001491    0.002985      0.002985
# 711            0.001011    0.002024      0.002024
# 711            0.001011    0.002024      0.002024
# 711            0.001011    0.002024      0.002024
# 711            0.001011    0.002024      0.002024
# 712            0.001644    0.003289      0.003289
# 713            0.000972    0.001946      0.001946
# 714            0.002039    0.004082      0.004082
# 715            0.000934    0.001869      0.001869
# 716            0.000735    0.001471      0.001471
# 717            0.000735    0.001471      0.001471
# 718            0.000833    0.001667      0.001667
# 719            0.000833    0.001667      0.001667
# 719            0.000714    0.001429      0.001429
# 720            0.000833    0.001667      0.001667
# 720            0.000735    0.001471      0.001471
# 721            0.000833    0.001667      0.001667
#
# [800 rows x 13 columns]
